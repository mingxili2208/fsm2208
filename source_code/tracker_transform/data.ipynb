# %% [markdown]
# 8个定位点————坐标+yaw旋转 数据

# %%
# 主要代码保持不变
# 定义坐标系A(vive )下的点的姿态 (roll, yaw, pitch) 和位置 (x, y, z)
points_A = [
    {'position': [0.488, -1.444, -3.911], 'orientation': [np.radians(-89.12), np.radians(178.93), np.radians(-144.60)]},
    # 1
    {'position': [0.488, -1.444, -3.911], 'orientation': [np.radians(89.17), np.radians(-2.42), np.radians(-55.83)]},
    # 1'
    {'position': [0.488, -1.444, -3.911], 'orientation': [np.radians(89.26), np.radians(-0.91), np.radians(33.41)]},
    # 1
    {'position': [0.488, -1.444, -3.911], 'orientation': [np.radians(-88.21), np.radians(177.42), np.radians(125.21)]},
    # 1
    {'position': [0.0995, -1.426, -3.322], 'orientation': [np.radians(-89.23), np.radians(178.91), np.radians(-146.53)]},
    # 2'
    {'position': [-1.431,-1.396,-2.982], 'orientation': [np.radians(-89.47), np.radians(179.01), np.radians(-147.25)]},
    # 3
    {'position': [-1.835, -1.391, -3.247], 'orientation': [np.radians(-88.50), np.radians(179.74), np.radians(-143.67)]},
    # 4
    {'position': [-1.835, -1.391, -3.247], 'orientation': [np.radians(88.54), np.radians(-2.36), np.radians(-57.01) ]},
    # 4
    {'position': [-1.835, -1.391, -3.247], 'orientation': [np.radians(89.37), np.radians(-0.52), np.radians(33.16)]},
    # 4
    {'position': [-1.835, -1.391, -3.247], 'orientation': [np.radians(-88.84), np.radians(178.15), np.radians(123.45)]},
    # 4
    {'position': [-0.534, -1.399, -2.382], 'orientation': [np.radians(-88.29), np.radians(179.32), np.radians(-145.39)]},
    # 5
    {'position': [-1.426, -1.363, -1.053], 'orientation': [np.radians(-88.29),np.radians(-179.78), np.radians(-138.69)]},
    # 6'
    {'position': [-1.547, -1.354, -0.883], 'orientation': [np.radians(-88.09), np.radians(-179.89), np.radians(-143.52)]},
    # 7''
    {'position': [0.856, -1.416, -1.45], 'orientation': [np.radians(-88.07), np.radians(179.67), np.radians(-147.85)]},
    # 8'''
    {'position': [0.856, -1.416, -1.45], 'orientation': [np.radians(88.67), np.radians(-2.16), np.radians(-55.84)]},
    # 8
    {'position': [0.856, -1.416, -1.45], 'orientation': [np.radians(88.34), np.radians(-0.17), np.radians(33.04)]},
    # 8'
    {'position': [0.856, -1.416, -1.45], 'orientation': [np.radians(-87.15), np.radians(176.23), np.radians(124.54) ]},
    # 8
]
points_B = [
    {'position': [0.217, -2.05, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},              # 1        0
    {'position': [0.217, -2.05, 0], 'orientation': [np.radians(0), np.radians(90), np.radians(0)]},             # 1`       1
    {'position': [0.217, -2.05, 0], 'orientation': [np.radians(0), np.radians(180), np.radians(0)]},            # 1``      2
    {'position': [0.217, -2.05, 0], 'orientation': [np.radians(0), np.radians(270), np.radians(0)]},            # 1 ```    3
    {'position': [0.92, -2.05, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},               # 2`       4
    {'position': [2.05, -0.97, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},               # 3        5
    {'position': [2.05, -0.49, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},               # 4        6
    {'position': [2.05, -0.49, 0], 'orientation': [np.radians(0), np.radians(90), np.radians(0)]},              # 4`       7
    {'position': [2.05, -0.49, 0], 'orientation': [np.radians(0), np.radians(180), np.radians(0)]},             # 4``      8
    {'position': [2.05, -0.49, 0], 'orientation': [np.radians(0), np.radians(270), np.radians(0)]},             # 4```     9
    {'position': [2.05, -2.05, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},               # 5        10
    {'position': [3.648, -2.05, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},              # 6        11
    {'position': [3.858, -2.05, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},              # 7        12
    {'position': [2.05, -3.72, 0], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]},               # 8        13
    {'position': [2.05, -3.72, 0], 'orientation': [np.radians(0), np.radians(90), np.radians(0)]},              # 8`       14
    {'position': [2.05, -3.72, 0], 'orientation': [np.radians(0), np.radians(180), np.radians(0)]},             # 8``      15
    {'position': [2.05, -3.72, 0], 'orientation': [np.radians(0), np.radians(270), np.radians(0)]},             # 8```     16
]

# %% [markdown]
# 8+3个定位点与4个矩阵的16个顶点

# %%
points_A = [
{'position': [0.4837, -1.3233, -3.9461], 'orientation': [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]}, # 1 0
{'position': [0.4837, -1.3233, -3.9461], 'orientation': [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]}, # 1' 1
{'position': [0.4837, -1.3233, -3.9461], 'orientation': [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]}, # 1'' 2
{'position': [0.0887, -1.3250, -3.3597], 'orientation': [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]}, # 2 3
{'position': [0.0887, -1.3250, -3.3597], 'orientation': [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]}, # 2' 4
{'position': [0.0887, -1.3250, -3.3597], 'orientation': [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]}, # 2'' 5
{'position': [-1.8305, -1.3951, -3.2280], 'orientation': [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]}, # 3 6
{'position': [-1.8305, -1.3951, -3.2280], 'orientation': [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]},# 3' 7
{'position': [-1.8305, -1.3951, -3.2280], 'orientation': [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]}, # 3'' 8
{'position': [-1.4227, -1.3937, -2.9686], 'orientation': [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]}, # 4 9
{'position': [-1.4227, -1.3937, -2.9686], 'orientation': [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]},# 4' 10
{'position': [-1.4227, -1.3937, -2.9686], 'orientation': [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]}, # 4'' 11
{'position': [-0.5129, -1.3801, -2.3834], 'orientation': [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]}, # 5 12
{'position': [-0.5129, -1.3801, -2.3834], 'orientation': [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]},# 5' 13
{'position': [-0.5129, -1.3801, -2.3834], 'orientation': [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]}, # 5'' 14
{'position': [-1.3783, -1.3812, -1.0451], 'orientation': [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]}, # 6 15
{'position': [-1.3783, -1.3812, -1.0451], 'orientation': [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]},# 6' 16
{'position': [-1.3783, -1.3812, -1.0451], 'orientation': [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]}, # 6'' 17
{'position': [-1.5140, -1.3658, -0.8836], 'orientation': [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]}, # 7 18
{'position': [-1.5140, -1.3658, -0.8836], 'orientation': [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]},# 7' 19
{'position': [-1.5140, -1.3658, -0.8836], 'orientation': [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]}, # 7'' 20
{'position': [0.8674, -1.3706, -1.4933], 'orientation': [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]}, # 8 21
{'position': [0.8674, -1.3706, -1.4933], 'orientation': [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]}, # 8' 22
{'position': [0.8674, -1.3706, -1.4933], 'orientation': [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]}, # 8'' 23
{'position': [-0.7430, -1.4027, -4.5224], 'orientation': [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]}, # 9 24
{'position': [-0.7430, -1.4027, -4.5224], 'orientation': [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]},# 9' 25
{'position': [-0.7430, -1.4027, -4.5224], 'orientation': [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]}, # 9'' 26
{'position': [1.2366, -1.3754, -2.4360], 'orientation': [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]}, # 10 22 27
{'position': [1.2366, -1.3754, -2.4360], 'orientation': [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]}, # 10' 28
{'position': [1.2366, -1.3754, -2.4360], 'orientation': [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]}, # 10'' 29
{'position': [0.1292, -1.3711, -0.7029], 'orientation': [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]}, # 11 30
{'position': [0.1292, -1.3711, -0.7029], 'orientation': [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]}, # 11' 25 31
{'position': [0.1292, -1.3711, -0.7029], 'orientation': [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]}, # 11'' 32
# this is new 16 points
# 1
{'position': [-1.1228, -1.3120, -4.3271], 'orientation': [np.radians(0.8608), np.radians(-53.6911), np.radians(92.4604)]}, #1
{'position': [-1.4121, -1.3142, -3.9064], 'orientation': [np.radians(0.4280), np.radians(-61.1639), np.radians(92.2939)]}, #2
{'position': [-0.9877, -1.3225, -3.6291], 'orientation': [np.radians(-6.8813), np.radians(-65.2652), np.radians(97.5612)]}, #3
{'position': [-0.7143, -1.4099, -4.0170], 'orientation': [np.radians(-0.1467), np.radians(-64.8302), np.radians(89.7913)]},#4
# 2
{'position': [-2.2414, -1.3942, -2.6190], 'orientation': [np.radians(-1.0939), np.radians(-55.2967), np.radians(89.3419)]},#5
{'position': [-2.5227, -1.3905, -2.2047], 'orientation': [np.radians(-1.0837), np.radians(-55.8826), np.radians(89.3874)]},#6
{'position': [-2.1095, -1.3928, -1.9267], 'orientation': [np.radians(-0.0076), np.radians(-55.9562), np.radians(89.9423)]},#7
{'position': [-1.8286, -1.3967, -2.3420], 'orientation': [np.radians(-0.3516), np.radians(-61.4611), np.radians(89.5441)]},#8
# 3
{'position': [-0.0673, -1.3908, -1.1899], 'orientation': [np.radians(-0.8849), np.radians(-56.3085), np.radians(89.3281)]},#9
{'position': [-0.3366, -1.3817, -0.7836], 'orientation': [np.radians(-0.3274), np.radians(-54.8635), np.radians(89.7061)]},#10
{'position': [0.0801, -1.3763, -0.5090], 'orientation': [np.radians(-0.5654), np.radians(-55.0822), np.radians(89.4644)]}, #11
{'position': [0.3583, -1.3796, -0.9285], 'orientation': [np.radians(-2.0204), np.radians(-54.3347), np.radians(88.1416)]}, #12
# 4
{'position': [1.0222, -1.4046, -2.8521], 'orientation': [np.radians(-0.1376), np.radians(-60.9930), np.radians(90.1337)]}, #13
{'position': [0.7512, -1.3999, -2.4198], 'orientation': [np.radians(-1.7505), np.radians(-65.6642), np.radians(88.0347)]}, #14
{'position': [1.1732, -1.4018, -2.1531], 'orientation': [np.radians(-0.6117), np.radians(-59.5986), np.radians(88.9130)]}, #15
{'position': [1.4524, -1.4044, -2.5697], 'orientation': [np.radians(-0.4654), np.radians(-58.3503), np.radians(89.0828)]} #16
]
points_B = [
{'position': [0.217, 0, -2.05], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #0 0
{'position': [0.217, 0, -2.05], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #0' 1
{'position': [0.217, 0, -2.05], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #0'' 2
{'position': [0.92, 0, -2.05], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #1 3
{'position': [0.92, 0, -2.05], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #1' 4
{'position': [0.92, 0, -2.05], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #1'' 5
{'position': [2.05, 0, -0.97], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #2 6
{'position': [2.05, 0, -0.97], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #2' 7
{'position': [2.05, 0, -0.97], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #2'' 8
{'position': [2.05, 0, -0.49], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #3 9
{'position': [2.05, 0, -0.49], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #3' 10
{'position': [2.05, 0, -0.49], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #3'' 11
{'position': [2.05, 0, -2.05], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #4 12
{'position': [2.05, 0, -2.05], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #4' 13 7
{'position': [2.05, 0, -2.05], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #4'' 14
{'position': [3.648, 0, -2.05], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #5 15
{'position': [3.648, 0, -2.05], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #5' 16 10
{'position': [3.648, 0, -2.05], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #5'' 17
{'position': [3.858, 0, -2.05], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #6 18
{'position': [3.858, 0, -2.05], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #6' 19 13
{'position': [3.858, 0, -2.05], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #6'' 20
{'position': [2.05, 0, -3.72], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #7 21
{'position': [2.05, 0, -3.72], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #7' 22 16
{'position': [2.05, 0, -3.72], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #7'' 23
{'position': [0.405, 0.004, -0.725], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #8 24
{'position': [0.405, 0.004, -0.725], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #8' 25
{'position': [0.405, 0.004, -0.725], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #8'' 26
{'position': [1.053,0.004,-3.507], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #9 27
{'position': [1.053,0.004,-3.507], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #9' 28 22
{'position': [1.053,0.004,-3.507], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #9'' 29
{'position': [3.01,0.004,-3.527], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, #10 30
{'position': [3.01,0.004,-3.527], 'orientation': [np.radians(-90), np.radians(30), np.radians(0)]}, #10' 31 25
{'position': [3.01,0.004,-3.527], 'orientation': [np.radians(30), np.radians(0), np.radians(-20)]}, #10'' 32
#this is new 16 points
#0
{'position': [0.80,0,-0.50], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 33
{'position': [1.30,0,-0.50], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 34
{'position': [1.30,0,-0.99], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 35
{'position': [0.80,0,-1.00], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 36
#1
{'position': [2.80,0,-0.50], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 37
{'position': [3.30,0,-0.50], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 38
{'position': [3.30,0,-1.00], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 39
{'position': [2.80,0,-1.00], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 40
#2
{'position': [2.80,0,-3.10], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 41
{'position': [3.30,0,-3.10], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 42
{'position': [3.30,0,-3.60], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 43
{'position': [2.80,0,-3.60], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 44
#3
{'position': [0.80,0,-3.10], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 45
{'position': [1.30,0,-3.10], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 46
{'position': [1.30,0,-3.60], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]}, # 47
{'position': [0.80,0,-3.60], 'orientation': [np.radians(0), np.radians(0), np.radians(0)]} # 48
]

# %% [markdown]
# 原始数据----8+3个定位点与4个矩阵的16个顶点-------Point类

# %%
import numpy as np

#最新坐标
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [
    Point([0.4799, -1.3278, -3.9353], [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]),       # 1
    Point([0.4839, -1.3176, -3.9501], [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]), # 1'
    Point([0.4874, -1.3246, -3.9531], [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]),     # 1''
    Point([0.0849, -1.3360, -3.3517], [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]),       # 2
    Point([0.0897, -1.3227, -3.3566], [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]), # 2'
    Point([0.0915, -1.3165, -3.3709], [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]),     # 2''
    Point([-1.8325, -1.3999, -3.2219], [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]),      # 3
    Point([-1.8274, -1.3918, -3.2343], [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]),# 3'
    Point([-1.8318, -1.3937, -3.2280], [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]),    # 3''
    Point([-1.4225, -1.4020, -2.9691], [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]),     # 4
    Point([-1.4202, -1.3885, -2.9732], [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]),# 4'
    Point([-1.4256, -1.3908, -2.9636], [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]),    # 4''
    Point([-0.5136, -1.3886, -2.3799], [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]),     # 5
    Point([-0.5125, -1.3719, -2.3902], [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]),# 5'
    Point([-0.5127, -1.3798, -2.3802], [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]),    # 5''
    Point([-1.3815, -1.3870, -1.0412], [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]),      # 6
    Point([-1.3752, -1.3760, -1.0495], [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]),# 6'
    Point([-1.3782, -1.3806, -1.0446], [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]),    # 6''
    Point([-1.4998, -1.3819, -0.8639], [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]),     # 7
    Point([-1.5154, -1.3534, -0.8967], [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]),# 7'
    Point([-1.5270, -1.3621, -0.8903], [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]),    # 7''
    Point([0.8669, -1.3785, -1.4911], [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]),      # 8
    Point([0.8693, -1.3655, -1.4974], [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]), # 8'
    Point([0.8660, -1.3679, -1.4915], [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]),     # 8''
    Point([-0.7374, -1.4125, -4.5271], [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]),      # 9
    Point([-0.7443, -1.3969, -4.5221], [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]),#9'
    Point([-0.7475, -1.3988, -4.5180], [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]),    #9''
    Point([1.2270, -1.3718, -2.4375], [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]),       # 10
    Point([1.2464, -1.3614, -2.4503], [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]), #10'
    Point([1.2365, -1.3931, -2.4204], [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]),     #10''
    Point([0.1257, -1.3777, -0.7007], [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]),      # 11
    Point([0.1327, -1.3646, -0.7114], [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]), #11'
    Point([0.1294, -1.3712, -0.6966], [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]),     #11''
]

points_B = [
    Point([0.217, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #1
    Point([0.217, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #1'
    Point([0.217, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #1''
    Point([0.92, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #2
    Point([0.92, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #2'
    Point([0.92, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #2''
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),     #3
    Point([2.05, 0, -0.97], [np.radians(-90), np.radians(30), np.radians(0)]),  #3'
    Point([2.05, 0, -0.97], [np.radians(30), np.radians(0), np.radians(-20)]),  #3''
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),     #4
    Point([2.05, 0, -0.49], [np.radians(-90), np.radians(30), np.radians(0)]),  #4'
    Point([2.05, 0, -0.49], [np.radians(30), np.radians(0), np.radians(-20)]),  #4''
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #5
    Point([2.05, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #5'
    Point([2.05, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #5''
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #6
    Point([3.648, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #6'
    Point([3.648, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #6''
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #7
    Point([3.858, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #7'
    Point([3.858, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #7''
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),     #8
    Point([2.05, 0, -3.72], [np.radians(-90), np.radians(30), np.radians(0)]),  #8'
    Point([2.05, 0, -3.72], [np.radians(30), np.radians(0), np.radians(-20)]),  #8''
    Point([0.405, 0.004,-1.725], [np.radians(0), np.radians(0), np.radians(0)]),     #9
    Point([0.405, 0.004,-1.725], [np.radians(-90), np.radians(30), np.radians(0)]),  #9'
    Point([0.405, 0.004,-1.725], [np.radians(30), np.radians(0), np.radians(-20)]),  #9''
    Point([1.053, 0.004, -3.507], [np.radians(0), np.radians(0), np.radians(0)]),     #10
    Point([1.053, 0.004, -3.507], [np.radians(-90), np.radians(30), np.radians(0)]),  #10'
    Point([1.053, 0.004, -3.507], [np.radians(30), np.radians(0), np.radians(-20)]),  #10''
    Point([3.01, 0.004, -3.527], [np.radians(0), np.radians(0), np.radians(0)]),     #11
    Point([3.01, 0.004, -3.527], [np.radians(-90), np.radians(30), np.radians(0)]),  #11'
    Point([3.01, 0.004, -3.527], [np.radians(30), np.radians(0), np.radians(-20)]),  #11''
]

# %% [markdown]
# 第二次采集
# 平均后-------8+3个定位点与4个矩阵的16个顶点（position&orientation）-------Point类

# %%
import numpy as np

#最新坐标----取平均后
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [

    Point([0.4837, -1.3233, -3.9461], [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]),       # 1 0
    Point([0.4837, -1.3233, -3.9461], [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]), # 1'   1
    Point([0.4837, -1.3233, -3.9461], [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]),     # 1'' 2
    Point([0.0887, -1.3250, -3.3597], [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]),       # 2 3
    Point([0.0887, -1.3250, -3.3597], [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]), # 2'   4
    Point([0.0887, -1.3250, -3.3597], [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]),     # 2'' 5
    Point([-1.8305, -1.3951, -3.2280], [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]),      # 3 6
    Point([-1.8305, -1.3951, -3.2280], [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]),# 3'    7
    Point([-1.8305, -1.3951, -3.2280], [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]),    # 3''  8
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]),     # 4  9
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]),# 4'     10
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]),    # 4''  11
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]),     # 5  12
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]),# 5'     13
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]),    # 5'' 14
    Point([-1.3783, -1.3812, -1.0451], [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]),      # 6  15
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]),# 6'    16
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]),    # 6''   17
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]),     # 7  18
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]),# 7'    19
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]),    # 7''   20
    Point([0.8674, -1.3706, -1.4933], [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]),      # 8   21
    Point([0.8674, -1.3706, -1.4933], [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]), # 8'      22
    Point([0.8674, -1.3706, -1.4933], [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]),     # 8''   23
    Point([-0.7430, -1.4027, -4.5224], [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]),      # 9   24
    Point([-0.7430, -1.4027, -4.5224], [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]),# 9'      25
    Point([-0.7430, -1.4027, -4.5224], [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]),    # 9''   26
    Point([1.2366, -1.3754, -2.4360], [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]),       # 10  22 27
    Point([1.2366, -1.3754, -2.4360], [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]), # 10'     28
    Point([1.2366, -1.3754, -2.4360], [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]),     # 10''    29
    Point([0.1292, -1.3711, -0.7029], [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]),      # 11    30
    Point([0.1292, -1.3711, -0.7029], [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]), # 11'   25 31
    Point([0.1292, -1.3711, -0.7029], [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]),     # 11''  32
    #this is new 16 points
    #1
    Point([-1.1228, -1.3120, -4.3271], [np.radians(0.8608), np.radians(-53.6911), np.radians(92.4604)]), #1
    Point([-1.4121, -1.3142, -3.9064], [np.radians(0.4280), np.radians(-61.1639), np.radians(92.2939)]), #2
    Point([-0.9877, -1.3225, -3.6291], [np.radians(-6.8813), np.radians(-65.2652), np.radians(97.5612)]), #3
    Point([-0.7143, -1.4099, -4.0170], [np.radians(-0.1467), np.radians(-64.8302), np.radians(89.7913)]),#4
    #2
    Point([-2.2414, -1.3942, -2.6190], [np.radians(-1.0939), np.radians(-55.2967), np.radians(89.3419)]),#5
    Point([-2.5227, -1.3905, -2.2047], [np.radians(-1.0837), np.radians(-55.8826), np.radians(89.3874)]),#6
    Point([-2.1095, -1.3928, -1.9267], [np.radians(-0.0076), np.radians(-55.9562), np.radians(89.9423)]),#7
    Point([-1.8286, -1.3967, -2.3420], [np.radians(-0.3516), np.radians(-61.4611), np.radians(89.5441)]),#8
    #3
    Point([-0.0673, -1.3908, -1.1899], [np.radians(-0.8849), np.radians(-56.3085), np.radians(89.3281)]),#9
    Point([-0.3366, -1.3817, -0.7836], [np.radians(-0.3274), np.radians(-54.8635), np.radians(89.7061)]),#10
    Point([0.0801, -1.3763, -0.5090], [np.radians(-0.5654), np.radians(-55.0822), np.radians(89.4644)]), #11
    Point([0.3583, -1.3796, -0.9285], [np.radians(-2.0204), np.radians(-54.3347), np.radians(88.1416)]), #12
    #4
    Point([1.0222, -1.4046, -2.8521], [np.radians(-0.1376), np.radians(-60.9930), np.radians(90.1337)]), #13
    Point([0.7512, -1.3999, -2.4198], [np.radians(-1.7505), np.radians(-65.6642), np.radians(88.0347)]), #14
    Point([1.1732, -1.4018, -2.1531], [np.radians(-0.6117), np.radians(-59.5986), np.radians(88.9130)]), #15
    Point([1.4524, -1.4044, -2.5697], [np.radians(-0.4654), np.radians(-58.3503), np.radians(89.0828)])  #16
]


points_B = [
    Point([0.217, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #0    0
    Point([0.217, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #0'   1
    Point([0.217, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #0''  2
    Point([0.92, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #1    3
    Point([0.92, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #1'   4
    Point([0.92, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #1''  5
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),     #2    6
    Point([2.05, 0, -0.97], [np.radians(-90), np.radians(30), np.radians(0)]),  #2'   7
    Point([2.05, 0, -0.97], [np.radians(30), np.radians(0), np.radians(-20)]),  #2''  8
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),     #3    9
    Point([2.05, 0, -0.49], [np.radians(-90), np.radians(30), np.radians(0)]),  #3'   10
    Point([2.05, 0, -0.49], [np.radians(30), np.radians(0), np.radians(-20)]),  #3''  11
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #4    12
    Point([2.05, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #4'   13   7
    Point([2.05, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #4''  14
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #5    15
    Point([3.648, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #5'   16   10
    Point([3.648, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #5''  17
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #6    18
    Point([3.858, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #6'   19   13
    Point([3.858, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #6''  20
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),     #7    21
    Point([2.05, 0, -3.72], [np.radians(-90), np.radians(30), np.radians(0)]),  #7'   22   16
    Point([2.05, 0, -3.72], [np.radians(30), np.radians(0), np.radians(-20)]),  #7''  23
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),    #8   24
    Point([0.405, 0.004, -0.725], [np.radians(-90), np.radians(30), np.radians(0)]), #8'  25
    Point([0.405, 0.004, -0.725], [np.radians(30), np.radians(0), np.radians(-20)]), #8'' 26
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(0), np.radians(0)]),    #9     27
    Point([1.053,0.004,-3.507], [np.radians(-90), np.radians(30), np.radians(0)]), #9'    28  22
    Point([1.053,0.004,-3.507], [np.radians(30), np.radians(0), np.radians(-20)]), #9''   29
    Point([3.01,0.004,-3.527], [np.radians(0), np.radians(0), np.radians(0)]),     #10    30
    Point([3.01,0.004,-3.527], [np.radians(-90), np.radians(30), np.radians(0)]),  #10'   31  25
    Point([3.01,0.004,-3.527], [np.radians(30), np.radians(0), np.radians(-20)]),  #10''  32
    #this is new 16 points
    #0
    Point([0.80,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 33
    Point([1.30,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 34
    Point([1.30,0,-0.99], [np.radians(0), np.radians(0), np.radians(0)]),   # 35
    Point([0.80,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 36
    #1
    Point([2.80,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 37
    Point([3.30,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 38
    Point([3.30,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 39
    Point([2.80,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 40
    #2
    Point([2.80,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 41
    Point([3.30,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 42
    Point([3.30,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 43
    Point([2.80,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 44
    #3
    Point([0.80,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 45
    Point([1.30,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 46
    Point([1.30,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 47
    Point([0.80,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)])    # 48
]

# %% [markdown]
# 第三次采集————去掉奇异点————————
# 8+3个定位点与4个矩阵的16个顶点（position&orientation）-------Point类

# %%
    ##################A
    Point([0.4837, -1.3233, -3.9461], [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]),       # 1
 #   Point([0.0887, -1.3250, -3.3597], [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]),       # 2
    Point([-1.8305, -1.3951, -3.2280], [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]),      # 3
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]),     # 4
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]),     # 5
    Point([-1.3783, -1.3812, -1.0451], [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]),      # 6
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]),     # 7
 #   Point([0.8674, -1.3706, -1.4933], [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]),      # 8
    Point([-0.7430, -1.4027, -4.5224], [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]),      # 9
    Point([1.2366, -1.3754, -2.4360], [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]),       # 10
 #   Point([0.1292, -1.3711, -0.7029], [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]),      # 11


    Point([0.4837, -1.3233, -3.9461], [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]), # 1'
    Point([0.0887, -1.3250, -3.3597], [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]), # 2'
    Point([-1.8305, -1.3951, -3.2280], [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]),# 3'
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]),# 4'
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]),# 5'
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]),# 6'
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]),# 7'
    Point([0.8674, -1.3706, -1.4933], [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]), # 8'
    Point([-0.7430, -1.4027, -4.5224], [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]),# 9'
    Point([1.2366, -1.3754, -2.4360], [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]), # 10'
    Point([0.1292, -1.3711, -0.7029], [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]), # 11'


    Point([0.4837, -1.3233, -3.9461], [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]),     # 1''
    Point([0.0887, -1.3250, -3.3597], [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]),     # 2''
    Point([-1.8305, -1.3951, -3.2280], [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]),    # 3''
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]),    # 4''
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]),    # 5''
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]),    # 6''
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]),    # 7''
    Point([0.8674, -1.3706, -1.4933], [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]),     # 8''
    Point([-0.7430, -1.4027, -4.5224], [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]),    # 9''
    Point([1.2366, -1.3754, -2.4360], [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]),     # 10''
    Point([0.1292, -1.3711, -0.7029], [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]),     # 11''
    ############################B
    Point([0.217, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #1
    Point([0.92, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #2
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),     #3
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),     #4
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #5
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #6
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #7
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),     #8
    Point([0.405, 0.004,-1.725], [np.radians(0), np.radians(0), np.radians(0)]),     #9
    Point([1.053, 0.004, -3.507], [np.radians(0), np.radians(0), np.radians(0)]),     #10
    Point([3.01, 0.004, -3.527], [np.radians(0), np.radians(0), np.radians(0)]),     #11


    Point([0.217, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #1'
    Point([0.92, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #2'
    Point([2.05, 0, -0.97], [np.radians(-90), np.radians(30), np.radians(0)]),  #3'
    Point([2.05, 0, -0.49], [np.radians(-90), np.radians(30), np.radians(0)]),  #4'
    Point([2.05, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #5'
    Point([3.648, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #6'
    Point([3.858, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #7'
    Point([2.05, 0, -3.72], [np.radians(-90), np.radians(30), np.radians(0)]),  #8'
    Point([0.405, 0.004,-1.725], [np.radians(-90), np.radians(30), np.radians(0)]),  #9'
    Point([1.053, 0.004, -3.507], [np.radians(-90), np.radians(30), np.radians(0)]),  #10'
    Point([3.01, 0.004, -3.527], [np.radians(-90), np.radians(30), np.radians(0)]),  #11'

    Point([0.217, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #1''
    Point([0.92, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #2''
    Point([2.05, 0, -0.97], [np.radians(30), np.radians(0), np.radians(-20)]),  #3''
    Point([2.05, 0, -0.49], [np.radians(30), np.radians(0), np.radians(-20)]),  #4''
    Point([2.05, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #5''
    Point([3.648, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #6''
    Point([3.858, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #7''
    Point([2.05, 0, -3.72], [np.radians(30), np.radians(0), np.radians(-20)]),  #8''
    Point([0.405, 0.004,-1.725], [np.radians(30), np.radians(0), np.radians(-20)]),  #9''
    Point([1.053, 0.004, -3.507], [np.radians(30), np.radians(0), np.radians(-20)]),  #10''
    Point([3.01, 0.004, -3.527], [np.radians(30), np.radians(0), np.radians(-20)]),  #11''

# %% [markdown]
# 第三次采集————去掉更多奇异点————————
# 8+3个定位点与4个矩阵的16个顶点（position&orientation）-------Point类

# %%
# delete special points
import numpy as np

#最新坐标----取平均后
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [

    Point([0.4837, -1.3233, -3.9461], [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]),       # 1 0
#    Point([0.4837, -1.3233, -3.9461], [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]), # 1'   1
    Point([0.4837, -1.3233, -3.9461], [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]),     # 1'' 2
    Point([0.0887, -1.3250, -3.3597], [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]),       # 2 3
#    Point([0.0887, -1.3250, -3.3597], [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]), # 2'   4
    Point([0.0887, -1.3250, -3.3597], [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]),     # 2'' 5
#    Point([-1.8305, -1.3951, -3.2280], [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]),      # 3 6
#    Point([-1.8305, -1.3951, -3.2280], [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]),# 3'    7
#    Point([-1.8305, -1.3951, -3.2280], [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]),    # 3''  8
#    Point([-1.4227, -1.3937, -2.9686], [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]),     # 4  9
#    Point([-1.4227, -1.3937, -2.9686], [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]),# 4'     10
#    Point([-1.4227, -1.3937, -2.9686], [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]),    # 4''  11
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]),     # 5  12
#    Point([-0.5129, -1.3801, -2.3834], [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]),# 5'     13
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]),    # 5'' 14
    Point([-1.3783, -1.3812, -1.0451], [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]),      # 6  15
#    Point([-1.3783, -1.3812, -1.0451], [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]),# 6'    16
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]),    # 6''   17
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]),     # 7  18
#    Point([-1.5140, -1.3658, -0.8836], [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]),# 7'    19
  #   Point([-1.5140, -1.3658, -0.8836], [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]),    # 7''   20
  #  Point([0.8674, -1.3706, -1.4933], [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]),      # 8   21
#    Point([0.8674, -1.3706, -1.4933], [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]), # 8'      22
  #  Point([0.8674, -1.3706, -1.4933], [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]),     # 8''   23
  #  Point([-0.7430, -1.4027, -4.5224], [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]),      # 9   24
  #  Point([-0.7430, -1.4027, -4.5224], [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]),# 9'      25
  #  Point([-0.7430, -1.4027, -4.5224], [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]),    # 9''   26
  #  Point([1.2366, -1.3754, -2.4360], [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]),       # 10  22 27
#    Point([1.2366, -1.3754, -2.4360], [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]), # 10'     28
  #  Point([1.2366, -1.3754, -2.4360], [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]),     # 10''    29
  #  Point([0.1292, -1.3711, -0.7029], [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]),      # 11    30
#    Point([0.1292, -1.3711, -0.7029], [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]), # 11'   25 31
  #   Point([0.1292, -1.3711, -0.7029], [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]),     # 11''  32
    #this is new 16 points
    #1
  #  Point([-1.1228, -1.3120, -4.3271], [np.radians(0.8608), np.radians(-53.6911), np.radians(92.4604)]), #1
    Point([-1.4121, -1.3142, -3.9064], [np.radians(0.4280), np.radians(-61.1639), np.radians(92.2939)]), #2
    Point([-0.9877, -1.3225, -3.6291], [np.radians(-6.8813), np.radians(-65.2652), np.radians(97.5612)]), #3
    Point([-0.7143, -1.4099, -4.0170], [np.radians(-0.1467), np.radians(-64.8302), np.radians(89.7913)]),#4
    #2
    Point([-2.2414, -1.3942, -2.6190], [np.radians(-1.0939), np.radians(-55.2967), np.radians(89.3419)]),#5
    Point([-2.5227, -1.3905, -2.2047], [np.radians(-1.0837), np.radians(-55.8826), np.radians(89.3874)]),#6
    Point([-2.1095, -1.3928, -1.9267], [np.radians(-0.0076), np.radians(-55.9562), np.radians(89.9423)]),#7
    Point([-1.8286, -1.3967, -2.3420], [np.radians(-0.3516), np.radians(-61.4611), np.radians(89.5441)]),#8
    #3
    Point([-0.0673, -1.3908, -1.1899], [np.radians(-0.8849), np.radians(-56.3085), np.radians(89.3281)]),#9
    Point([-0.3366, -1.3817, -0.7836], [np.radians(-0.3274), np.radians(-54.8635), np.radians(89.7061)]),#10
    Point([0.0801, -1.3763, -0.5090], [np.radians(-0.5654), np.radians(-55.0822), np.radians(89.4644)]), #11
    Point([0.3583, -1.3796, -0.9285], [np.radians(-2.0204), np.radians(-54.3347), np.radians(88.1416)]), #12
    #4
    Point([1.0222, -1.4046, -2.8521], [np.radians(-0.1376), np.radians(-60.9930), np.radians(90.1337)]), #13
    Point([0.7512, -1.3999, -2.4198], [np.radians(-1.7505), np.radians(-65.6642), np.radians(88.0347)]), #14
    Point([1.1732, -1.4018, -2.1531], [np.radians(-0.6117), np.radians(-59.5986), np.radians(88.9130)]), #15
    Point([1.4524, -1.4044, -2.5697], [np.radians(-0.4654), np.radians(-58.3503), np.radians(89.0828)])  #16
]


points_B = [
    Point([0.217, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #0    0
#    Point([0.217, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #0'   1
    Point([0.217, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #0''  2
    Point([0.92, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #1    3
#    Point([0.92, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #1'   4
    Point([0.92, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #1''  5
#    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),     #2    6
#    Point([2.05, 0, -0.97], [np.radians(-90), np.radians(30), np.radians(0)]),  #2'   7
#    Point([2.05, 0, -0.97], [np.radians(30), np.radians(0), np.radians(-20)]),  #2''  8
#    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),     #3    9
#    Point([2.05, 0, -0.49], [np.radians(-90), np.radians(30), np.radians(0)]),  #3'   10
#    Point([2.05, 0, -0.49], [np.radians(30), np.radians(0), np.radians(-20)]),  #3''  11
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #4    12
#    Point([2.05, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]),  #4'   13   7
    Point([2.05, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]),  #4''  14
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #5    15
#    Point([3.648, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #5'   16   10
    Point([3.648, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #5''  17
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #6    18
#    Point([3.858, 0, -2.05], [np.radians(-90), np.radians(30), np.radians(0)]), #6'   19   13
  #  Point([3.858, 0, -2.05], [np.radians(30), np.radians(0), np.radians(-20)]), #6''  20
  #  Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),     #7    21
#    Point([2.05, 0, -3.72], [np.radians(-90), np.radians(30), np.radians(0)]),  #7'   22   16
  #  Point([2.05, 0, -3.72], [np.radians(30), np.radians(0), np.radians(-20)]),  #7''  23
  #  Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),    #8   24
  #  Point([0.405, 0.004, -0.725], [np.radians(-90), np.radians(30), np.radians(0)]), #8'  25
  #  Point([0.405, 0.004, -0.725], [np.radians(30), np.radians(0), np.radians(-20)]), #8'' 26
  #  Point([1.053,0.004,-3.507], [np.radians(0), np.radians(0), np.radians(0)]),    #9     27
#    Point([1.053,0.004,-3.507], [np.radians(-90), np.radians(30), np.radians(0)]), #9'    28  22
  #  Point([1.053,0.004,-3.507], [np.radians(30), np.radians(0), np.radians(-20)]), #9''   29
  #  Point([3.01,0.004,-3.527], [np.radians(0), np.radians(0), np.radians(0)]),     #10    30
#    Point([3.01,0.004,-3.527], [np.radians(-90), np.radians(30), np.radians(0)]),  #10'   31  25
  #  Point([3.01,0.004,-3.527], [np.radians(30), np.radians(0), np.radians(-20)]),  #10''  32
    #this is new 16 points
    #0
  #  Point([0.80,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 33
    Point([1.30,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 34
    Point([1.30,0,-0.99], [np.radians(0), np.radians(0), np.radians(0)]),   # 35
    Point([0.80,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 36
    #1
    Point([2.80,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 37
    Point([3.30,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 38
    Point([3.30,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 39
    Point([2.80,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 40
    #2
    Point([2.80,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 41
    Point([3.30,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 42
    Point([3.30,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 43
    Point([2.80,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 44
    #3
    Point([0.80,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 45
    Point([1.30,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 46
    Point([1.30,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 47
    Point([0.80,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)])    # 48
]

# %% [markdown]
# 新增方向----------------原始数据

# %%
# this is new point with 6 different direction
[x=0.4906, y=-1.2811, z=-3.9287, roll=-0.1904, yaw=-56.1830, pitch=90.7598]
[x=0.4920, y=-1.2817, z=-3.9266, roll=179.2069, yaw=-148.1846, pitch=-90.2653]
[x=0.4929, y=-1.2861, z=-3.9439, roll=-1.1469, yaw=33.4709, pitch=90.9847]
#2
[x=0.0808, y=-1.2827, z=-3.3186, roll=0.4149, yaw=-59.9988, pitch=87.1458]
[x=0.0803, y=-1.2852, z=-3.3250, roll=-176.1434, yaw=-148.4816, pitch=-87.9381]
[x=0.0803, y=-1.2843, z=-3.3221, roll=3.6167, yaw=33.2743, pitch=88.5044]

# %% [markdown]
# 8+3个定位点+4个矩阵的16个顶点+6个新方位（position&orientation）-------Point类

# %%
# delete special points
import numpy as np

#最新坐标----取平均后
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [

    Point([0.4837, -1.3233, -3.9461], [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]),       # 1 0
    Point([0.4837, -1.3233, -3.9461], [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]), # 1'   1
    Point([0.4837, -1.3233, -3.9461], [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]),     # 1'' 2
    Point([0.0887, -1.3250, -3.3597], [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]),       # 2 3
    Point([0.0887, -1.3250, -3.3597], [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]), # 2'   4
    Point([0.0887, -1.3250, -3.3597], [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]),     # 2'' 5
    Point([-1.8305, -1.3951, -3.2280], [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]),      # 3 6
    Point([-1.8305, -1.3951, -3.2280], [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]),# 3'    7
    Point([-1.8305, -1.3951, -3.2280], [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]),    # 3''  8
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]),     # 4  9
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]),# 4'     10
    Point([-1.4227, -1.3937, -2.9686], [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]),    # 4''  11
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]),     # 5  12
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]),# 5'     13
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]),    # 5'' 14
    Point([-1.3783, -1.3812, -1.0451], [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]),      # 6  15
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]),# 6'    16
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]),    # 6''   17
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]),     # 7  18
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]),# 7'    19
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]),    # 7''   20
    Point([0.8674, -1.3706, -1.4933], [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]),      # 8   21
    Point([0.8674, -1.3706, -1.4933], [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]), # 8'      22
    Point([0.8674, -1.3706, -1.4933], [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]),     # 8''   23
    Point([-0.7430, -1.4027, -4.5224], [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]),      # 9   24
    Point([-0.7430, -1.4027, -4.5224], [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]),# 9'      25
    Point([-0.7430, -1.4027, -4.5224], [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]),    # 9''   26
    Point([1.2366, -1.3754, -2.4360], [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]),       # 10  22 27
    Point([1.2366, -1.3754, -2.4360], [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]), # 10'     28
    Point([1.2366, -1.3754, -2.4360], [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]),     # 10''    29
    Point([0.1292, -1.3711, -0.7029], [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]),      # 11    30
    Point([0.1292, -1.3711, -0.7029], [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]), # 11'   25 31
    Point([0.1292, -1.3711, -0.7029], [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]),     # 11''  32
    #this is new 16 points
    #1
    Point([-1.1228, -1.3120, -4.3271], [np.radians(0.8608), np.radians(-53.6911), np.radians(92.4604)]), #1
    Point([-1.4121, -1.3142, -3.9064], [np.radians(0.4280), np.radians(-61.1639), np.radians(92.2939)]), #2
    Point([-0.9877, -1.3225, -3.6291], [np.radians(-6.8813), np.radians(-65.2652), np.radians(97.5612)]), #3
    Point([-0.7143, -1.4099, -4.0170], [np.radians(-0.1467), np.radians(-64.8302), np.radians(89.7913)]),#4
    #2
    Point([-2.2414, -1.3942, -2.6190], [np.radians(-1.0939), np.radians(-55.2967), np.radians(89.3419)]),#5
    Point([-2.5227, -1.3905, -2.2047], [np.radians(-1.0837), np.radians(-55.8826), np.radians(89.3874)]),#6
    Point([-2.1095, -1.3928, -1.9267], [np.radians(-0.0076), np.radians(-55.9562), np.radians(89.9423)]),#7
    Point([-1.8286, -1.3967, -2.3420], [np.radians(-0.3516), np.radians(-61.4611), np.radians(89.5441)]),#8
    #3
    Point([-0.0673, -1.3908, -1.1899], [np.radians(-0.8849), np.radians(-56.3085), np.radians(89.3281)]),#9
    Point([-0.3366, -1.3817, -0.7836], [np.radians(-0.3274), np.radians(-54.8635), np.radians(89.7061)]),#10
    Point([0.0801, -1.3763, -0.5090], [np.radians(-0.5654), np.radians(-55.0822), np.radians(89.4644)]), #11
    Point([0.3583, -1.3796, -0.9285], [np.radians(-2.0204), np.radians(-54.3347), np.radians(88.1416)]), #12
    #4
    Point([1.0222, -1.4046, -2.8521], [np.radians(-0.1376), np.radians(-60.9930), np.radians(90.1337)]), #13
    Point([0.7512, -1.3999, -2.4198], [np.radians(-1.7505), np.radians(-65.6642), np.radians(88.0347)]), #14
    Point([1.1732, -1.4018, -2.1531], [np.radians(-0.6117), np.radians(-59.5986), np.radians(88.9130)]), #15
    Point([1.4524, -1.4044, -2.5697], [np.radians(-0.4654), np.radians(-58.3503), np.radians(89.0828)])  #16

    # this is new point with 6 different direction
    Point([0.4906, -1.2811, -3.9287,], [np.radians(-0.1904), np.radians(-56.1830), np.radians(90.7598)]), #0
    Point([0.4920, -1.2817, -3.9266,], [np.radians(179.2069), np.radians(-148.1846), np.radians(-90.2653)]), #1
    Point([0.4929, -1.2861, -3.9439,], [np.radians(-1.1469), np.radians(33.4709), np.radians(90.9847)]), #2
    Point([0.0808, -1.2827, -3.3186,], [np.radians(0.4149), np.radians(-59.9988), np.radians(87.1458)]), #3
    Point([0.0803, -1.2852, -3.3250,], [np.radians(-176.1434), np.radians(-148.4816), np.radians(-87.9381)]), #4
    Point([0.0803, -1.2843, -3.3221,], [np.radians(3.6167), np.radians(33.2743), np.radians(88.5044)]), #5

]


points_B = [
    Point([0.217, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #0    0
    Point([0.217, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]), #0'   1
    Point([0.217, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]), #0''  2
    Point([0.92, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #1    3
    Point([0.92, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]),  #1'   4
    Point([0.92, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]),  #1''  5
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),     #2    6
    Point([2.05, 0.015, -0.97], [np.radians(30),np.radians(-90),  np.radians(0)]),  #2'   7
    Point([2.05, 0.01, -0.97], [np.radians(0),np.radians(30), np.radians(-20)]),  #2''  8
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),     #3    9
    Point([2.05, 0.015, -0.49], [np.radians(30),np.radians(-90),  np.radians(0)]),  #3'   10
    Point([2.05, 0.01, -0.49], [np.radians(0),np.radians(30), np.radians(-20)]),  #3''  11
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #4    12
    Point([2.05, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]),  #4'   13   7
    Point([2.05, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]),  #4''  14
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #5    15
    Point([3.648, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]), #5'   16   10
    Point([3.648, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]), #5''  17
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #6    18
    Point([3.858, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]), #6'   19   13
    Point([3.858, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]), #6''  20
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),     #7    21
    Point([2.05, 0.015, -3.72], [np.radians(30),np.radians(-90),  np.radians(0)]),  #7'   22   16
    Point([2.05, 0.01, -3.72], [np.radians(0),np.radians(30), np.radians(-20)]),  #7''  23
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),    #8   24
    Point([0.405, 0.004, -0.725], [np.radians(30),np.radians(-90),  np.radians(0)]), #8'  25
    Point([0.405, 0.004, -0.725], [np.radians(0),np.radians(30), np.radians(-20)]), #8'' 26
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(0), np.radians(0)]),    #9     27
    Point([1.053,0.004,-3.507], [np.radians(30),np.radians(-90),  np.radians(0)]), #9'    28  22
    Point([1.053,0.004,-3.507], [np.radians(0),np.radians(30), np.radians(-20)]), #9''   29
    Point([3.01,0.004,-3.527], [np.radians(0), np.radians(0), np.radians(0)]),     #10    30
    Point([3.01,0.004,-3.527], [np.radians(30),np.radians(-90),  np.radians(0)]),  #10'   31  25
    Point([3.01,0.004,-3.527], [np.radians(0),np.radians(30), np.radians(-20)]),  #10''  32
    #this is new 16 points
    #0
    Point([0.80,0,-0.503], [np.radians(0), np.radians(0), np.radians(0)]),   # 33
    Point([1.30,0,-0.502], [np.radians(0), np.radians(0), np.radians(0)]),   # 34
    Point([1.30,0,-1.001], [np.radians(0), np.radians(0), np.radians(0)]),   # 35
    Point([0.80,0,-1.001], [np.radians(0), np.radians(0), np.radians(0)]),   # 36
    #1
    Point([2.80,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 37
    Point([3.30,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 38
    Point([3.30,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 39
    Point([2.80,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 40
    #2
    Point([2.80,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 41
    Point([3.30,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 42
    Point([3.30,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 43
    Point([2.80,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 44
    #3
    Point([0.815,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 45
    Point([1.316,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 46
    Point([1.310,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 47
    Point([0.808,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)])    # 48
    # this is new point with 6 different direction
    #1'     x    y    z          r               y                 p
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)])
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)])
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)])
    #2'
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)])
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)])
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)])
]

# %% [markdown]
# 8+3个定位点与4个矩阵的16个顶点（position&orientation）+11个点的33个新方位-------Point类

# %%
# delete special points & use the update points
import numpy as np

#最新坐标----取平均后
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [

    Point([0.4837, -1.3233, -3.9461], [np.radians(0.1025), np.radians(-55.7886), np.radians(91.8146)]),       # 1 0
 #   Point([0.4837, -1.3233, -3.9461], [np.radians(-179.7870), np.radians(-144.8536), np.radians(-120.9998)]), # 1'   1
    Point([0.4837, -1.3233, -3.9461], [np.radians(-22.6521), np.radians(-32.9473), np.radians(90.0343)]),     # 1'' 2
    Point([0.0887, -1.3250, -3.3597], [np.radians(2.3271), np.radians(-59.5605), np.radians(92.3895)]),       # 2 3
 #   Point([0.0887, -1.3250, -3.3597], [np.radians(-178.6286), np.radians(-147.6686), np.radians(-120.2366)]), # 2'   4
    Point([0.0887, -1.3250, -3.3597], [np.radians(-22.1813), np.radians(-34.4269), np.radians(86.8067)]),     # 2'' 5
 #   Point([-1.8305, -1.3951, -3.2280], [np.radians(0.6676), np.radians(-60.7822), np.radians(90.0414)]),      # 3 6
  #  Point([-1.8305, -1.3951, -3.2280], [np.radians(-177.4059), np.radians(-147.7991), np.radians(-120.0628)]),# 3'    7
   # Point([-1.8305, -1.3951, -3.2280], [np.radians(-22.4285), np.radians(-34.8151), np.radians(87.4277)]),    # 3''  8
  #  Point([-1.4227, -1.3937, -2.9686], [np.radians(-0.0218), np.radians(-61.0372), np.radians(88.9864)]),     # 4  9
  #  Point([-1.4227, -1.3937, -2.9686], [np.radians(-179.0243), np.radians(-148.9208), np.radians(-120.0628)]),# 4'     10
  #  Point([-1.4227, -1.3937, -2.9686], [np.radians(-23.1839), np.radians(-37.6294), np.radians(86.9329)]),    # 4''  11
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-0.2046), np.radians(-58.0093), np.radians(89.8167)]),     # 5  12
#    Point([-0.5129, -1.3801, -2.3834], [np.radians(-178.9994), np.radians(-147.5538), np.radians(-120.1558)]),# 5'     13
    Point([-0.5129, -1.3801, -2.3834], [np.radians(-22.7840), np.radians(-33.8897), np.radians(88.7093)]),    # 5'' 14
    Point([-1.3783, -1.3812, -1.0451], [np.radians(0.4369), np.radians(-54.3746), np.radians(89.1041)]),      # 6  15
#    Point([-1.3783, -1.3812, -1.0451], [np.radians(-176.0058), np.radians(-148.8773), np.radians(-117.6707)]),# 6'    16
    Point([-1.3783, -1.3812, -1.0451], [np.radians(-22.0088), np.radians(-33.5773), np.radians(87.1209)]),    # 6''   17
    Point([-1.5140, -1.3658, -0.8836], [np.radians(-0.4083), np.radians(-60.5462), np.radians(89.7344)]),     # 7  18
#    Point([-1.5140, -1.3658, -0.8836], [np.radians(-177.6953), np.radians(-145.8537), np.radians(-119.6940)]),# 7'    19
#    Point([-1.5140, -1.3658, -0.8836], [np.radians(-21.8242), np.radians(-32.5503), np.radians(88.6979)]),    # 7''   20
#    Point([0.8674, -1.3706, -1.4933], [np.radians(-2.5103), np.radians(-57.6808), np.radians(87.8262)]),      # 8   21
#    Point([0.8674, -1.3706, -1.4933], [np.radians(-177.6567), np.radians(-147.0740), np.radians(-119.2254)]), # 8'      22
#    Point([0.8674, -1.3706, -1.4933], [np.radians(-23.1031), np.radians(-33.9084), np.radians(88.1074)]),     # 8''   23
#    Point([-0.7430, -1.4027, -4.5224], [np.radians(0.0960), np.radians(-54.4806), np.radians(91.2216)]),      # 9   24
#    Point([-0.7430, -1.4027, -4.5224], [np.radians(-178.8582), np.radians(-145.7330), np.radians(-120.3380)]),# 9'      25
#    Point([-0.7430, -1.4027, -4.5224], [np.radians(-21.3784), np.radians(-29.6438), np.radians(89.6642)]),    # 9''   26
#   Point([1.2366, -1.3754, -2.4360], [np.radians(0.7148), np.radians(-58.8044), np.radians(90.8907)]),       # 10  22 27
#    Point([1.2366, -1.3754, -2.4360], [np.radians(-179.4645), np.radians(-147.4631), np.radians(-120.9428)]), # 10'     28
#    Point([1.2366, -1.3754, -2.4360], [np.radians(-21.9546), np.radians(-34.9327), np.radians(94.6225)]),     # 10''    29
#    Point([0.1292, -1.3711, -0.7029], [np.radians(-2.7652), np.radians(-57.0650), np.radians(87.6298)]),      # 11    30
#    Point([0.1292, -1.3711, -0.7029], [np.radians(-179.1399), np.radians(-144.1354), np.radians(-120.2723)]), # 11'   25 31
#    Point([0.1292, -1.3711, -0.7029], [np.radians(-23.9618), np.radians(-37.5303), np.radians(92.6984)]),     # 11''  32
    #this is new 16 points
    #1
#    Point([-1.1228, -1.3120, -4.3271], [np.radians(0.8608), np.radians(-53.6911), np.radians(92.4604)]), #1
    Point([-1.4121, -1.3142, -3.9064], [np.radians(0.4280), np.radians(-61.1639), np.radians(92.2939)]), #2
#    Point([-0.9877, -1.3225, -3.6291], [np.radians(-6.8813), np.radians(-65.2652), np.radians(97.5612)]), #3
    Point([-0.7143, -1.4099, -4.0170], [np.radians(-0.1467), np.radians(-64.8302), np.radians(89.7913)]),#4
    #2
    Point([-2.2414, -1.3942, -2.6190], [np.radians(-1.0939), np.radians(-55.2967), np.radians(89.3419)]),#5
    Point([-2.5227, -1.3905, -2.2047], [np.radians(-1.0837), np.radians(-55.8826), np.radians(89.3874)]),#6
    Point([-2.1095, -1.3928, -1.9267], [np.radians(-0.0076), np.radians(-55.9562), np.radians(89.9423)]),#7
    Point([-1.8286, -1.3967, -2.3420], [np.radians(-0.3516), np.radians(-61.4611), np.radians(89.5441)]),#8
    #3
    Point([-0.0673, -1.3908, -1.1899], [np.radians(-0.8849), np.radians(-56.3085), np.radians(89.3281)]),#9
    Point([-0.3366, -1.3817, -0.7836], [np.radians(-0.3274), np.radians(-54.8635), np.radians(89.7061)]),#10
    Point([0.0801, -1.3763, -0.5090], [np.radians(-0.5654), np.radians(-55.0822), np.radians(89.4644)]), #11
    Point([0.3583, -1.3796, -0.9285], [np.radians(-2.0204), np.radians(-54.3347), np.radians(88.1416)]), #12
    #4
    Point([1.0222, -1.4046, -2.8521], [np.radians(-0.1376), np.radians(-60.9930), np.radians(90.1337)]), #13
    Point([0.7512, -1.3999, -2.4198], [np.radians(-1.7505), np.radians(-65.6642), np.radians(88.0347)]), #14
    Point([1.1732, -1.4018, -2.1531], [np.radians(-0.6117), np.radians(-59.5986), np.radians(88.9130)]), #15
    Point([1.4524, -1.4044, -2.5697], [np.radians(-0.4654), np.radians(-58.3503), np.radians(89.0828)]),  #16
    # this is new point with 6 different direction
    Point([0.4906, -1.2811, -3.9287,], [np.radians(-0.1904), np.radians(-56.1830), np.radians(90.7598)]), #0
    Point([0.4920, -1.2817, -3.9266,], [np.radians(179.2069), np.radians(-148.1846), np.radians(-90.2653)]), #1
    Point([0.4929, -1.2861, -3.9439,], [np.radians(-1.1469), np.radians(33.4709), np.radians(90.9847)]), #2
    Point([0.0808, -1.2827, -3.3186,], [np.radians(0.4149), np.radians(-59.9988), np.radians(87.1458)]), #3
    Point([0.0803, -1.2852, -3.3250,], [np.radians(-176.1434), np.radians(-148.4816), np.radians(-87.9381)]), #4
    Point([0.0803, -1.2843, -3.3221,], [np.radians(3.6167), np.radians(33.2743), np.radians(88.5044)]), #5
    #3
    Point([-1.4332, -1.3579, -3.0101], [np.radians(3.3906), np.radians(-57.5494), np.radians(92.6096)])
    Point([-1.4335, -1.3580, -3.0140], [np.radians(-179.2934), np.radians(-145.7496), np.radians(-90.7195)])
    Point([-1.4317, -1.3556, -3.0046], [np.radians(0.1914), np.radians(34.0085), np.radians(92.1104)])
    #4
    Point([-1.8310, -1.3561, -3.2609], [np.radians(3.3361), np.radians(-55.9886), np.radians(92.5137)])
    Point([-1.8331, -1.3580, -3.2692], [np.radians(-179.9233), np.radians(-147.2942), np.radians(-91.6695)])
    Point([-1.8305, -1.3559, -3.2602], [np.radians(0.3013), np.radians(35.0746), np.radians(92.1814)])
    #5
    Point([-0.5236, -1.3480, -2.4197], [np.radians(0.7017), np.radians(-56.5258), np.radians(90.4932)])
    Point([-0.5233, -1.3475, -2.4205], [np.radians(-179.9303), np.radians(-148.5801), np.radians(-90.3337)])
    Point([-0.5216, -1.3421, -2.4085], [np.radians(0.3145), np.radians(34.3669), np.radians(90.3373)])
    #6
    Point([-1.3967, -1.3797, -1.0781], [np.radians(1.3633), np.radians(-55.5799), np.radians(90.2613)])
    Point([-1.3905, -1.3767, -1.0781], [np.radians(-178.4583), np.radians(-146.8788), np.radians(-89.9101)])
    Point([-1.3946, -1.3778, -1.0762], [np.radians(1.5277), np.radians(34.5399), np.radians(89.8219)])
    #7
    Point([-1.5114, -1.3830, -0.9008], [np.radians(1.2181), np.radians(-55.3441), np.radians(90.6436)])
    Point([-1.5070, -1.3792, -0.9007], [np.radians(-179.4732), np.radians(-145.5065), np.radians(-90.4384)])
    Point([-1.5106, -1.3810, -0.8993], [np.radians(0.6979), np.radians(33.4920), np.radians(90.3505)])
    #8
    Point([0.8711, -1.3832, -1.4822], [np.radians(-1.1910), np.radians(-57.3527), np.radians(88.5614)])
    Point([0.8682, -1.3816, -1.4825], [np.radians(-179.6739), np.radians(-147.3753), np.radians(-88.6797)])
    Point([0.8707, -1.3855, -1.4848], [np.radians(0.3528), np.radians(33.1809), np.radians(89.2791)])
    #9
    Point([-0.7368, -1.3940, -4.5174], [np.radians(0.1287), np.radians(-55.4812), np.radians(90.7442)])
    Point([-0.7341, -1.3909, -4.5103], [np.radians(179.2466), np.radians(-144.7978), np.radians(-89.9364)])
    Point([-0.7351, -1.3888, -4.5008], [np.radians(-1.0588), np.radians(32.9105), np.radians(90.4965)])
    #10
    Point([1.2365, -1.3786, -2.4241], [np.radians(0.4565), np.radians(-57.3756), np.radians(90.6007)])
    Point([1.2382, -1.3810, -2.4316], [np.radians(-179.9541), np.radians(-147.5195), np.radians(-89.9003)])
    Point([1.2415, -1.3864, -2.4397], [np.radians(0.0576), np.radians(31.4427), np.radians(90.5722)])
    #11
    Point([0.1352, -1.3765, -0.7127], [np.radians(-1.6455), np.radians(-55.2843), np.radians(88.6130)])
    Point([0.1366, -1.3772, -0.7153], [np.radians(-179.6177), np.radians(-145.0708), np.radians(-88.4101)])
    Point([0.1342, -1.3767, -0.7141], [np.radians(0.5587), np.radians(36.3590), np.radians(88.5927)])

]


points_B = [
    Point([0.217, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #0    0
#    Point([0.217, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]), #0'   1
    Point([0.217, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]), #0''  2
    Point([0.92, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #1    3
#    Point([0.92, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]),  #1'   4
    Point([0.92, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]),  #1''  5
#    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),     #2    6
#    Point([2.05, 0.015, -0.97], [np.radians(30),np.radians(-90),  np.radians(0)]),  #2'   7
#    Point([2.05, 0.01, -0.97], [np.radians(0),np.radians(30), np.radians(-20)]),  #2''  8
#    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),     #3    9
#    Point([2.05, 0.015, -0.49], [np.radians(30),np.radians(-90),  np.radians(0)]),  #3'   10
#    Point([2.05, 0.01, -0.49], [np.radians(0),np.radians(30), np.radians(-20)]),  #3''  11
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),     #4    12
#    Point([2.05, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]),  #4'   13   7
    Point([2.05, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]),  #4''  14
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #5    15
#    Point([3.648, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]), #5'   16   10
    Point([3.648, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]), #5''  17
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),    #6    18
#    Point([3.858, 0.015, -2.05], [np.radians(30),np.radians(-90),  np.radians(0)]), #6'   19   13
#    Point([3.858, 0.01, -2.05], [np.radians(0),np.radians(30), np.radians(-20)]), #6''  20
#    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),     #7    21
#    Point([2.05, 0.015, -3.72], [np.radians(30),np.radians(-90),  np.radians(0)]),  #7'   22   16
#    Point([2.05, 0.01, -3.72], [np.radians(0),np.radians(30), np.radians(-20)]),  #7''  23
#    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),    #8   24
#    Point([0.405, 0.004, -0.725], [np.radians(30),np.radians(-90),  np.radians(0)]), #8'  25
#    Point([0.405, 0.004, -0.725], [np.radians(0),np.radians(30), np.radians(-20)]), #8'' 26
#    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(0), np.radians(0)]),    #9     27
#    Point([1.053,0.004,-3.507], [np.radians(30),np.radians(-90),  np.radians(0)]), #9'    28  22
#    Point([1.053,0.004,-3.507], [np.radians(0),np.radians(30), np.radians(-20)]), #9''   29
#    Point([3.01,0.004,-3.527], [np.radians(0), np.radians(0), np.radians(0)]),     #10    30
#    Point([3.01,0.004,-3.527], [np.radians(30),np.radians(-90),  np.radians(0)]),  #10'   31  25
#    Point([3.01,0.004,-3.527], [np.radians(0),np.radians(30), np.radians(-20)]),  #10''  32
    #this is new 16 points
    #0
#    Point([0.80,0,-0.503], [np.radians(0), np.radians(0), np.radians(0)]),   # 33
    Point([1.30,0,-0.502], [np.radians(0), np.radians(0), np.radians(0)]),   # 34
#    Point([1.30,0,-1.001], [np.radians(0), np.radians(0), np.radians(0)]),   # 35
    Point([0.80,0,-1.001], [np.radians(0), np.radians(0), np.radians(0)]),   # 36
    #1
    Point([2.80,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 37
    Point([3.30,0,-0.50], [np.radians(0), np.radians(0), np.radians(0)]),   # 38
    Point([3.30,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 39
    Point([2.80,0,-1.00], [np.radians(0), np.radians(0), np.radians(0)]),   # 40
    #2
    Point([2.80,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 41
    Point([3.30,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 42
    Point([3.30,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 43
    Point([2.80,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 44
    #3
    Point([0.815,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 45
    Point([1.316,0,-3.10], [np.radians(0), np.radians(0), np.radians(0)]),   # 46
    Point([1.310,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),   # 47
    Point([0.808,0,-3.60], [np.radians(0), np.radians(0), np.radians(0)]),    # 48
    # this is new point with 6 different direction
    #1'     x    y    z          r               y                 p
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #2'
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),

    #3'
    Point([2.05, 0, -0.97],   [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -0.97],   [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -0.97],   [np.radians(0), np.radians(90), np.radians(0)]),
    #4'
    Point([2.05, 0, -0.49],   [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -0.49],   [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -0.49],   [np.radians(0), np.radians(90), np.radians(0)]),
    #5'
    Point([2.05, 0, -2.05],   [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -2.05],   [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -2.05],   [np.radians(0), np.radians(90), np.radians(0)]),
    #6'
    Point([3.648, 0, -2.05],  [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.648, 0, -2.05],  [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.648, 0, -2.05],  [np.radians(0), np.radians(90), np.radians(0)]),
    #7'
    Point([3.858, 0, -2.05],  [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.858, 0, -2.05],  [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.858, 0, -2.05],  [np.radians(0), np.radians(90), np.radians(0)]),
    #8'
    Point([2.05, 0, -3.72],   [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -3.72],   [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -3.72],   [np.radians(0), np.radians(90), np.radians(0)]),
    #9'
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(90), np.radians(0)]),
    #10'
    Point([1.053,0.004,-3.507],   [np.radians(0), np.radians(0), np.radians(0)]),
    Point([1.053,0.004,-3.507],   [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([1.053,0.004,-3.507],   [np.radians(0), np.radians(90), np.radians(0)]),
    #11'
    Point([3.01,0.004,-3.527],    [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.01,0.004,-3.527],    [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.01,0.004,-3.527],    [np.radians(0), np.radians(90), np.radians(0)]),
]

# %% [markdown]
# 8个定位点的新方向的原始数据----A

# %%
#data
#3
[x=-1.4332, y=-1.3579, z=-3.0101, roll=3.3906, yaw=-57.5494, pitch=92.6096]
[x=-1.4335, y=-1.3580, z=-3.0140, roll=-179.2934, yaw=-145.7496, pitch=-90.7195]
[x=-1.4317, y=-1.3556, z=-3.0046, roll=0.1914, yaw=34.0085, pitch=92.1104]
#4
[x=-1.8310, y=-1.3561, z=-3.2609, roll=3.3361, yaw=-55.9886, pitch=92.5137]
[x=-1.8331, y=-1.3580, z=-3.2692, roll=-179.9233, yaw=-147.2942, pitch=-91.6695]
[x=-1.8305, y=-1.3559, z=-3.2602, roll=0.3013, yaw=35.0746, pitch=92.1814]
#5
[x=-0.5236, y=-1.3480, z=-2.4197, roll=0.7017, yaw=-56.5258, pitch=90.4932]
[x=-0.5233, y=-1.3475, z=-2.4205, roll=-179.9303, yaw=-148.5801, pitch=-90.3337]
[x=-0.5216, y=-1.3421, z=-2.4085, roll=0.3145, yaw=34.3669, pitch=90.3373]
#6
[x=-1.3967, y=-1.3797, z=-1.0781, roll=1.3633, yaw=-55.5799, pitch=90.2613]
[x=-1.3905, y=-1.3767, z=-1.0781, roll=-178.4583, yaw=-146.8788, pitch=-89.9101]
[x=-1.3946, y=-1.3778, z=-1.0762, roll=1.5277, yaw=34.5399, pitch=89.8219]
#7
[x=-1.5114, y=-1.3830, z=-0.9008, roll=1.2181, yaw=-55.3441, pitch=90.6436]
[x=-1.5070, y=-1.3792, z=-0.9007, roll=-179.4732, yaw=-145.5065, pitch=-90.4384]
[x=-1.5106, y=-1.3810, z=-0.8993, roll=0.6979, yaw=33.4920, pitch=90.3505]
#8
[x=0.8711, y=-1.3832, z=-1.4822, roll=-1.1910, yaw=-57.3527, pitch=88.5614]
[x=0.8682, y=-1.3816, z=-1.4825, roll=-179.6739, yaw=-147.3753, pitch=-88.6797]
[x=0.8707, y=-1.3855, z=-1.4848, roll=0.3528, yaw=33.1809, pitch=89.2791]
#9
[x=-0.7368, y=-1.3940, z=-4.5174, roll=0.1287, yaw=-55.4812, pitch=90.7442]
[x=-0.7341, y=-1.3909, z=-4.5103, roll=179.2466, yaw=-144.7978, pitch=-89.9364]
[x=-0.7351, y=-1.3888, z=-4.5008, roll=-1.0588, yaw=32.9105, pitch=90.4965]
#10
[x=1.2365, y=-1.3786, z=-2.4241, roll=0.4565, yaw=-57.3756, pitch=90.6007]
[x=1.2382, y=-1.3810, z=-2.4316, roll=-179.9541, yaw=-147.5195, pitch=-89.9003]
[x=1.2415, y=-1.3864, z=-2.4397, roll=0.0576, yaw=31.4427, pitch=90.5722]
#11
[x=0.1352, y=-1.3765, z=-0.7127, roll=-1.6455, yaw=-55.2843, pitch=88.6130]
[x=0.1366, y=-1.3772, z=-0.7153, roll=-179.6177, yaw=-145.0708, pitch=-88.4101]
[x=0.1342, y=-1.3767, z=-0.7141, roll=0.5587, yaw=36.3590, pitch=88.5927]

# %% [markdown]
# 8+3个定位点与4个矩阵的16个顶点（position&orientation）+11个点的33个新方位-------Point类————第二次采集

# %%
# delete special points & use the update points
import numpy as np

#最新坐标----取平均后
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [
    #this is new 16 points
    #1
#    Point([-1.1228, -1.3120, -4.3271], [np.radians(0.8608), np.radians(-53.6911), np.radians(92.4604)]), #1
    Point([-1.4121, -1.3142, -3.9064], [np.radians(0.4280), np.radians(-61.1639), np.radians(92.2939)]), #2
#    Point([-0.9877, -1.3225, -3.6291], [np.radians(-6.8813), np.radians(-65.2652), np.radians(97.5612)]), #3
    Point([-0.7143, -1.4099, -4.0170], [np.radians(-0.1467), np.radians(-64.8302), np.radians(89.7913)]),#4
    #2
    Point([-2.2414, -1.3942, -2.6190], [np.radians(-1.0939), np.radians(-55.2967), np.radians(89.3419)]),#5
    Point([-2.5227, -1.3905, -2.2047], [np.radians(-1.0837), np.radians(-55.8826), np.radians(89.3874)]),#6
    Point([-2.1095, -1.3928, -1.9267], [np.radians(-0.0076), np.radians(-55.9562), np.radians(89.9423)]),#7
    Point([-1.8286, -1.3967, -2.3420], [np.radians(-0.3516), np.radians(-61.4611), np.radians(89.5441)]),#8
    #3
    Point([-0.0673, -1.3908, -1.1899], [np.radians(-0.8849), np.radians(-56.3085), np.radians(89.3281)]),#9
    Point([-0.3366, -1.3817, -0.7836], [np.radians(-0.3274), np.radians(-54.8635), np.radians(89.7061)]),#10
    Point([0.0801, -1.3763, -0.5090],  [np.radians(-0.5654), np.radians(-55.0822), np.radians(89.4644)]), #11
    Point([0.3583, -1.3796, -0.9285],  [np.radians(-2.0204), np.radians(-54.3347), np.radians(88.1416)]), #12
    #4
    Point([1.0222, -1.4046, -2.8521],  [np.radians(-0.1376), np.radians(-60.9930), np.radians(90.1337)]), #13
    Point([0.7512, -1.3999, -2.4198],  [np.radians(-1.7505), np.radians(-65.6642), np.radians(88.0347)]), #14
    Point([1.1732, -1.4018, -2.1531],  [np.radians(-0.6117), np.radians(-59.5986), np.radians(88.9130)]), #15
    Point([1.4524, -1.4044, -2.5697],  [np.radians(-0.4654), np.radians(-58.3503), np.radians(89.0828)]),  #16
    # this is new point with 6 different direction
    Point([0.4906, -1.2811, -3.9287,], [np.radians(-0.1904), np.radians(-56.1830), np.radians(90.7598)]), #0
    Point([0.4920, -1.2817, -3.9266,], [np.radians(179.2069), np.radians(-148.1846), np.radians(-90.2653)]), #1
    Point([0.4929, -1.2861, -3.9439,], [np.radians(-1.1469), np.radians(33.4709), np.radians(90.9847)]), #2
    Point([0.0808, -1.2827, -3.3186,], [np.radians(0.4149), np.radians(-59.9988), np.radians(87.1458)]), #3
    Point([0.0803, -1.2852, -3.3250,], [np.radians(-176.1434), np.radians(-148.4816), np.radians(-87.9381)]), #4
    Point([0.0803, -1.2843, -3.3221,], [np.radians(3.6167), np.radians(33.2743), np.radians(88.5044)]), #5
    #3
    Point([-1.4328, -1.3571, -3.0095], [np.radians(3.3906), np.radians(-57.5494), np.radians(92.6096)]),
    Point([-1.4328, -1.3571, -3.0095], [np.radians(-179.2934), np.radians(-145.7496), np.radians(-90.7195)]),
    Point([-1.4328, -1.3571, -3.0095], [np.radians(0.1914), np.radians(34.0085), np.radians(92.1104)]),
    #4
    Point([-1.8315, -1.3566, -3.2634], [np.radians(3.3361), np.radians(-55.9886), np.radians(92.5137)]),
    Point([-1.8315, -1.3566, -3.2634], [np.radians(-179.9233), np.radians(-147.2942), np.radians(-91.6695)]),
    Point([-1.8315, -1.3566, -3.2634], [np.radians(0.3013), np.radians(35.0746), np.radians(92.1814)]),
    #5
    Point([-0.5228, -1.3458, -2.4162], [np.radians(0.7017), np.radians(-56.5258), np.radians(90.4932)]),
    Point([-0.5228, -1.3458, -2.4162], [np.radians(-179.9303), np.radians(-148.5801), np.radians(-90.3337)]),
    Point([-0.5228, -1.3458, -2.4162], [np.radians(0.3145), np.radians(34.3669), np.radians(90.3373)]),
    #6
    Point([-1.3939, -1.3780, -1.0774], [np.radians(1.3633), np.radians(-55.5799), np.radians(90.2613)]),
    Point([-1.3939, -1.3780, -1.0774], [np.radians(-178.4583), np.radians(-146.8788), np.radians(-89.9101)]),
    Point([-1.3939, -1.3780, -1.0774], [np.radians(1.5277), np.radians(34.5399), np.radians(89.8219)]),
    #7
    Point([-1.5096, -1.3810, -0.9002], [np.radians(1.2181), np.radians(-55.3441), np.radians(90.6436)]),
    Point([-1.5096, -1.3810, -0.9002], [np.radians(-179.4732), np.radians(-145.5065), np.radians(-90.4384)]),
    Point([-1.5096, -1.3810, -0.9002], [np.radians(0.6979), np.radians(33.4920), np.radians(90.3505)]),
    #8
    Point([ 0.8700, -1.3834, -1.4831], [np.radians(-1.1910), np.radians(-57.3527), np.radians(88.5614)]),
    Point([ 0.8700, -1.3834, -1.4831], [np.radians(-179.6739), np.radians(-147.3753), np.radians(-88.6797)]),
    Point([ 0.8700, -1.3834, -1.4831], [np.radians(0.3528), np.radians(33.1809), np.radians(89.2791)]),
    #9
    Point([-0.7353, -1.3912, -4.5095], [np.radians(0.1287), np.radians(-55.4812), np.radians(90.7442)]),
    Point([-0.7353, -1.3912, -4.5095], [np.radians(179.2466), np.radians(-144.7978), np.radians(-89.9364)]),
    Point([-0.7353, -1.3912, -4.5095], [np.radians(-1.0588), np.radians(32.9105), np.radians(90.4965)]),
    #10
    Point([ 1.2387, -1.3820, -2.4318], [np.radians(0.4565), np.radians(-57.3756), np.radians(90.6007)]),
    Point([ 1.2387, -1.3820, -2.4318], [np.radians(-179.9541), np.radians(-147.5195), np.radians(-89.9003)]),
    Point([ 1.2387, -1.3820, -2.4318], [np.radians(0.0576), np.radians(31.4427), np.radians(90.5722)]),
    #11
    Point([ 0.1353, -1.3768, -0.7140], [np.radians(-1.6455), np.radians(-55.2843), np.radians(88.6130)]),
    Point([ 0.1353, -1.3768, -0.7140], [np.radians(-179.6177), np.radians(-145.0708), np.radians(-88.4101)]),
    Point([ 0.1353, -1.3768, -0.7140], [np.radians(0.5587), np.radians(36.3590), np.radians(88.5927)])

]


points_B = [
    #this is new 16 points
    #0
#    Point([0.80,0,-0.503], [np.radians(0), np.radians(0), np.radians(0)]),   # 33
    Point([1.30,0,-0.502],  [np.radians(0), np.radians(0), np.radians(0)]),   # 34
#    Point([1.30,0,-1.001], [np.radians(0), np.radians(0), np.radians(0)]),   # 35
    Point([0.80,0,-1.001],  [np.radians(0), np.radians(0), np.radians(0)]),   # 36
    #1
    Point([2.80,0,-0.50],   [np.radians(0), np.radians(0), np.radians(0)]),   # 37
    Point([3.30,0,-0.50],   [np.radians(0), np.radians(0), np.radians(0)]),   # 38
    Point([3.30,0,-1.00],   [np.radians(0), np.radians(0), np.radians(0)]),   # 39
    Point([2.80,0,-1.00],   [np.radians(0), np.radians(0), np.radians(0)]),   # 40
    #2
    Point([2.80,0,-3.10],   [np.radians(0), np.radians(0), np.radians(0)]),   # 41
    Point([3.30,0,-3.10],   [np.radians(0), np.radians(0), np.radians(0)]),   # 42
    Point([3.30,0,-3.60],   [np.radians(0), np.radians(0), np.radians(0)]),   # 43
    Point([2.80,0,-3.60],   [np.radians(0), np.radians(0), np.radians(0)]),   # 44
    #3
    Point([0.815,0,-3.10],  [np.radians(0), np.radians(0), np.radians(0)]),   # 45
    Point([1.316,0,-3.10],  [np.radians(0), np.radians(0), np.radians(0)]),   # 46
    Point([1.310,0,-3.60],  [np.radians(0), np.radians(0), np.radians(0)]),   # 47
    Point([0.808,0,-3.60],  [np.radians(0), np.radians(0), np.radians(0)]),    # 48
    # this is new point with 6 different direction
    #1'     x    y    z          r               y                 p
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #2'
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),

    #3'
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(90), np.radians(0)]),
    #4'
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(90), np.radians(0)]),
    #5'
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #6'
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #7'
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #8'
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(90), np.radians(0)]),
    #9'
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(90), np.radians(0)]),
    #10'
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(90), np.radians(0)]),
    #11'
    Point([3.01,0.004,-3.527], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.01,0.004,-3.527], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.01,0.004,-3.527], [np.radians(0), np.radians(90), np.radians(0)]),
]

# %% [markdown]
# 下面的点可以获得0.0189与0.681的拟合精度

# %%
# delete special points & use the update points
import numpy as np

#最新坐标----取平均后
# 定义坐标系A下的点的位置 (x, y, z)和姿态 (roll, yaw, pitch)
points_A = [
    # this is new point with 6 different direction
    Point([0.4918, -1.2814, -3.9277,], [np.radians(-0.1904), np.radians(-56.1830), np.radians(0)]), #0
    Point([0.4918, -1.2814, -3.9277,], [np.radians(0), np.radians(-148.1846), np.radians(0)]), #1
    Point([0.4918, -1.2814, -3.9277,], [np.radians(-1.1469), np.radians(33.4709), np.radians(0)]), #2

    Point([0.0808, -1.2827, -3.3186,], [np.radians(0.4149), np.radians(-59.9988), np.radians(0)]), #3
    Point([0.0803, -1.2852, -3.3250,], [np.radians(0), np.radians(-148.4816), np.radians(0)]), #4
    Point([0.0803, -1.2843, -3.3221,], [np.radians(3.6167), np.radians(33.2743), np.radians(0)]), #5
    #3
    Point([-1.4328, -1.3571, -3.0095], [np.radians(3.3906), np.radians(-57.5494), np.radians(0)]),
    Point([-1.4328, -1.3571, -3.0095], [np.radians(0), np.radians(-145.7496), np.radians(0)]),
    Point([-1.4328, -1.3571, -3.0095], [np.radians(0.1914), np.radians(34.0085), np.radians(0)]),
    #4
    Point([-1.8315, -1.3566, -3.2634], [np.radians(3.3361), np.radians(-55.9886), np.radians(0)]),
    Point([-1.8315, -1.3566, -3.2634], [np.radians(0), np.radians(-147.2942), np.radians(0)]),
    Point([-1.8315, -1.3566, -3.2634], [np.radians(0.3013), np.radians(35.0746), np.radians(0)]),
    #5
    Point([-0.5228, -1.3458, -2.4162], [np.radians(0.7017), np.radians(-56.5258), np.radians(0)]),
    Point([-0.5228, -1.3458, -2.4162], [np.radians(0), np.radians(-148.5801), np.radians(0)]),
    Point([-0.5228, -1.3458, -2.4162], [np.radians(0.3145), np.radians(34.3669), np.radians(0)]),
    #6
    Point([-1.3939, -1.3780, -1.0774], [np.radians(1.3633), np.radians(-55.5799), np.radians(0)]),
    Point([-1.3939, -1.3780, -1.0774], [np.radians(0), np.radians(-146.8788), np.radians(0)]),
    Point([-1.3939, -1.3780, -1.0774], [np.radians(1.5277), np.radians(34.5399), np.radians(0)]),
    #7
    Point([-1.5096, -1.3810, -0.9002], [np.radians(1.2181), np.radians(-55.3441), np.radians(0)]),
    Point([-1.5096, -1.3810, -0.9002], [np.radians(0), np.radians(-145.5065), np.radians(0)]),
    Point([-1.5096, -1.3810, -0.9002], [np.radians(0.6979), np.radians(33.4920), np.radians(0)]),
    #8
    Point([ 0.8700, -1.3834, -1.4831], [np.radians(-1.1910), np.radians(-57.3527), np.radians(0)]),
    Point([ 0.8700, -1.3834, -1.4831], [np.radians(0), np.radians(-147.3753), np.radians(0)]),
    Point([ 0.8700, -1.3834, -1.4831], [np.radians(0.3528), np.radians(33.1809), np.radians(0)]),
    #9
    Point([-0.7353, -1.3912, -4.5095], [np.radians(0.1287), np.radians(-55.4812), np.radians(0)]),
    Point([-0.7353, -1.3912, -4.5095], [np.radians(0), np.radians(-144.7978), np.radians(0)]),
    Point([-0.7353, -1.3912, -4.5095], [np.radians(-1.0588), np.radians(32.9105), np.radians(0)]),
    #10
    Point([ 1.2387, -1.3820, -2.4318], [np.radians(0.4565), np.radians(-57.3756), np.radians(0)]),
    Point([ 1.2387, -1.3820, -2.4318], [np.radians(0), np.radians(-147.5195), np.radians(0)]),
    Point([ 1.2387, -1.3820, -2.4318], [np.radians(0.0576), np.radians(31.4427), np.radians(0)]),
    #11
    Point([ 0.1353, -1.3768, -0.7140], [np.radians(-1.6455), np.radians(-55.2843), np.radians(0)]),
    Point([ 0.1353, -1.3768, -0.7140], [np.radians(-0), np.radians(-145.0708), np.radians(0)]),
    Point([ 0.1353, -1.3768, -0.7140], [np.radians(0.5587), np.radians(36.3590), np.radians(0)])

]


points_B = [

    # this is new point with 6 different direction
    #1'     x    y    z          r               y                 p
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.217, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #2'
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.92, 0.08, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),

    #3'
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -0.97], [np.radians(0), np.radians(90), np.radians(0)]),
    #4'
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -0.49], [np.radians(0), np.radians(90), np.radians(0)]),
    #5'
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #6'
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.648, 0, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #7'
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.858, 0, -2.05], [np.radians(0), np.radians(90), np.radians(0)]),
    #8'
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([2.05, 0, -3.72], [np.radians(0), np.radians(90), np.radians(0)]),
    #9'
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([0.405, 0.004, -0.725], [np.radians(0), np.radians(90), np.radians(0)]),
    #10'
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([1.053,0.004,-3.507], [np.radians(0), np.radians(90), np.radians(0)]),
    #11'
    Point([3.091,0.004,-3.527], [np.radians(0), np.radians(0), np.radians(0)]),
    Point([3.091,0.004,-3.527], [np.radians(0), np.radians(-90), np.radians(0)]),
    Point([3.091,0.004,-3.527], [np.radians(0), np.radians(90), np.radians(0)]),
]

# %%
position_A=[
    [0.4918, -1.2814, -3.9277],
    [0.4918, -1.2814, -3.9277],
    [0.4918, -1.2814, -3.9277],
    [0.0808, -1.2827, -3.3186],
    [0.0803, -1.2852, -3.3250],
    [0.0803, -1.2843, -3.3221],
    [-1.4328, -1.3571, -3.0095],
    [-1.4328, -1.3571, -3.0095],
    [-1.4328, -1.3571, -3.0095],
    [-1.8315, -1.3566, -3.2634],
    [-1.8315, -1.3566, -3.2634],
    [-1.8315, -1.3566, -3.2634],
    [-0.5228, -1.3458, -2.4162],
    [-0.5228, -1.3458, -2.4162],
    [-0.5228, -1.3458, -2.4162],
    [-1.3939, -1.3780, -1.0774],
    [-1.3939, -1.3780, -1.0774],
    [-1.3939, -1.3780, -1.0774],
    [-1.5096, -1.3810, -0.9002],
    [-1.5096, -1.3810, -0.9002],
    [-1.5096, -1.3810, -0.9002],
    [ 0.8700, -1.3834, -1.4831],
    [ 0.8700, -1.3834, -1.4831],
    [ 0.8700, -1.3834, -1.4831],
    [-0.7353, -1.3912, -4.5095],
    [-0.7353, -1.3912, -4.5095],
    [-0.7353, -1.3912, -4.5095],
    [ 1.2387, -1.3820, -2.4318],
    [ 1.2387, -1.3820, -2.4318],
    [ 1.2387, -1.3820, -2.4318],
    [ 0.1353, -1.3768, -0.7140],
    [ 0.1353, -1.3768, -0.7140],
    [ 0.1353, -1.3768, -0.7140],
    #
    [0.4837, -1.3233, -3.9461],
    [0.4837, -1.3233, -3.9461],
    [0.4837, -1.3233, -3.9461],
    [0.0887, -1.3250, -3.3597],
    [0.0887, -1.3250, -3.3597],
    [0.0887, -1.3250, -3.3597],
    [-1.8305, -1.3951, -3.2280],
    [-1.8305, -1.3951, -3.2280],
    [-1.8305, -1.3951, -3.2280],
    [-1.4227, -1.3937, -2.9686],
    [-1.4227, -1.3937, -2.9686],
    [-1.4227, -1.3937, -2.9686],
    [-0.5129, -1.3801, -2.3834],
    [-0.5129, -1.3801, -2.3834],
    [-0.5129, -1.3801, -2.3834],
    [-1.3783, -1.3812, -1.0451],
    [-1.3783, -1.3812, -1.0451],
    [-1.3783, -1.3812, -1.0451],
    [-1.5140, -1.3658, -0.8836],
    [-1.5140, -1.3658, -0.8836],
    [-1.5140, -1.3658, -0.8836],
    [0.8674, -1.3706, -1.4933],
    [0.8674, -1.3706, -1.4933],
    [0.8674, -1.3706, -1.4933],
    [-0.7430, -1.4027, -4.5224],
    [-0.7430, -1.4027, -4.5224],
    [-0.7430, -1.4027, -4.5224],
    [1.2366, -1.3754, -2.4360],
    [1.2366, -1.3754, -2.4360],
    [1.2366, -1.3754, -2.4360],
    [0.1292, -1.3711, -0.7029],
    [0.1292, -1.3711, -0.7029],
    [0.1292, -1.3711, -0.7029],
        #1
    [-1.1228, -1.3120, -4.3271],
    [-1.4121, -1.3142, -3.9064],
    [-0.9877, -1.3225, -3.6291],
    [-0.7143, -1.4099, -4.0170],
        #2
    [-2.2414, -1.3942, -2.6190],
    [-2.5227, -1.3905, -2.2047],
    [-2.1095, -1.3928, -1.9267],
    [-1.8286, -1.3967, -2.3420],
        #3
    [-0.0673, -1.3908, -1.1899],
    [-0.3366, -1.3817, -0.7836],
    [0.0801, -1.3763, -0.5090],
    [0.3583, -1.3796, -0.9285],
        #4
    [1.0222, -1.4046, -2.8521],
    [0.7512, -1.3999, -2.4198],
    [1.1732, -1.4018, -2.1531],
    [1.4524, -1.4044, -2.5697]

]

positions_B=[
    [0.217, 0.08, -2.05],
    [0.217, 0.08, -2.05],
    [0.217, 0.08, -2.05],
        #2'
    [0.92, 0.08, -2.05],
    [0.92, 0.08, -2.05],
    [0.92, 0.08, -2.05],
        #3'
    [2.05, 0, -0.97],
    [2.05, 0, -0.97],
    [2.05, 0, -0.97],
        #4'
    [2.05, 0, -0.49],
    [2.05, 0, -0.49],
    [2.05, 0, -0.49],
        #5'
    [2.05, 0, -2.05],
    [2.05, 0, -2.05],
    [2.05, 0, -2.05],
        #6'
    [3.648, 0, -2.05],
    [3.648, 0, -2.05],
    [3.648, 0, -2.05],
        #7'
    [3.858, 0, -2.05],
    [3.858, 0, -2.05],
    [3.858, 0, -2.05],
        #8'
    [2.05, 0, -3.72],
    [2.05, 0, -3.72],
    [2.05, 0, -3.72],
        #9'
    [0.405, 0.004, -0.725],
    [0.405, 0.004, -0.725],
    [0.405, 0.004, -0.725],
        #10'
    [1.053,0.004,-3.507],
    [1.053,0.004,-3.507],
    [1.053,0.004,-3.507],
        #11'
    [3.091,0.004,-3.527],
    [3.091,0.004,-3.527],
    [3.091,0.004,-3.527],
    #
    [0.217, 0, -2.05],
    [0.217, 0.015, -2.05],
    [0.217, 0.01, -2.05],
    [0.92, 0, -2.05],
    [0.92, 0.015, -2.05],
    [0.92, 0.01, -2.05],
    [2.05, 0, -0.97],
    [2.05, 0.015, -0.97],
    [2.05, 0.01, -0.97],
    [2.05, 0, -0.49],
    [2.05, 0.015, -0.49],
    [2.05, 0.01, -0.49],
    [2.05, 0, -2.05],
    [2.05, 0.015, -2.05],
    [2.05, 0.01, -2.05],
    [3.648, 0, -2.05],
    [3.648, 0.015, -2.05],
    [3.648, 0.01, -2.05],
    [3.858, 0, -2.05],
    [3.858, 0.015, -2.05],
    [3.858, 0.01, -2.05],
    [2.05, 0, -3.72],
    [2.05, 0.015, -3.72],
    [2.05, 0.01, -3.72],
    [0.405, 0.004, -0.725],
    [0.405, 0.004, -0.725],
    [0.405, 0.004, -0.725],
    [1.053,0.004,-3.507],
    [1.053,0.004,-3.507],
    [1.053,0.004,-3.507],
    [3.01,0.004,-3.527],
    [3.01,0.004,-3.527],
    [3.01,0.004,-3.527],
        #0
    [0.80,0,-0.503],
    [1.30,0,-0.502],
    [1.30,0,-1.001],
    [0.80,0,-1.001],
        #1
    [2.80,0,-0.50],
    [3.30,0,-0.50],
    [3.30,0,-1.00],
    [2.80,0,-1.00],
        #2
    [2.80,0,-3.10],
    [3.30,0,-3.10],
    [3.30,0,-3.60],
    [2.80,0,-3.60],
        #3
    [0.815,0,-3.10],
    [1.316,0,-3.10],
    [1.310,0,-3.60],
    [0.808,0,-3.60],

]

# %% [markdown]
# 4个点处的yaw角度旋转数据（每次旋转43-46度）-----原始数据

# %%
[x=0.4535, y=-1.2178, z=-3.9541, roll=2.9726, yaw=33.3364, pitch=0.5471],       #0
[x=0.4416, y=-1.2139, z=-3.9458, roll=1.2630, yaw=80.7374, pitch=2.2648],       #47.4
[x=0.4414, y=-1.2140, z=-3.9461, roll=2.5626, yaw=124.2558, pitch=0.4429],      #+44.25
[x=0.4423, y=-1.2143, z=-3.9471, roll=-2.1893, yaw=167.4090, pitch=0.1604],     #+43
[x=0.4448, y=-1.2148, z=-3.9482, roll=-2.5408, yaw=-150.4331, pitch=0.5022],    #+43.8
[x=0.4500, y=-1.2165, z=-3.9515, roll=-0.4480, yaw=-101.3775, pitch=2.1169],    #+49.1
[x=0.4479, y=-1.2157, z=-3.9503, roll=2.8603, yaw=-57.9998, pitch=1.4325],      #+43.4

[x=0.0795, y=-1.2211, z=-3.3622, roll=2.5324, yaw=-55.4875, pitch=91.6268]      #
[x=0.0802, y=-1.2229, z=-3.3670, roll=179.5182, yaw=-101.1943, pitch=-91.5991]
[x=0.0800, y=-1.2239, z=-3.3694, roll=-179.1793, yaw=-146.1972, pitch=-90.4901]
[x=0.0798, y=-1.2228, z=-3.3655, roll=-178.7287, yaw=168.6552, pitch=-90.3057]
[x=0.0794, y=-1.2219, z=-3.3637, roll=-177.7245, yaw=123.3208, pitch=-90.9030]
[x=0.0790, y=-1.2226, z=-3.3658, roll=-0.2886, yaw=80.7334, pitch=92.1552]
[x=0.0787, y=-1.2240, z=-3.3695, roll=1.3069, yaw=32.1998, pitch=90.6428]
[x=0.0779, y=-1.2236, z=-3.3702, roll=1.7077, yaw=-57.5099, pitch=90.4336]

[x=-0.6603, y=-1.1338, z=-4.5943, roll=2.5719, yaw=-54.3468, pitch=93.9034]
[x=-0.5106, y=-1.1269, z=-4.8208, roll=0.3964, yaw=-52.7843, pitch=91.9049]
[x=-0.5112, y=-1.1284, z=-4.8262, roll=-0.5675, yaw=-7.1385, pitch=91.5855]
[x=-0.5100, y=-1.1271, z=-4.8214, roll=-2.0975, yaw=34.0582, pitch=91.7108]
[x=-0.5094, y=-1.1263, z=-4.8163, roll=-6.3252, yaw=74.8816, pitch=95.5746]
[x=-0.5093, y=-1.1264, z=-4.8163, roll=179.9958, yaw=124.6180, pitch=-91.4012]
[x=-0.5094, y=-1.1260, z=-4.8152, roll=178.5895, yaw=172.8003, pitch=-90.8504]
[x=-0.5092, y=-1.1257, z=-4.8139, roll=177.5008, yaw=-145.1366, pitch=-91.3455]
[x=-0.5101, y=-1.1267, z=-4.8169, roll=163.3548, yaw=-95.9682, pitch=-104.9276]
[x=-0.5101, y=-1.1266, z=-4.8168, roll=0.8704, yaw=-53.2292, pitch=92.7668]
[x=-0.9715, y=-1.1296, z=-4.5853, roll=-0.4302, yaw=-6.7862, pitch=93.0999]
[x=-0.9712, y=-1.1295, z=-4.5833, roll=-2.7291, yaw=36.0104, pitch=93.3343]
[x=-0.9695, y=-1.1289, z=-4.5844, roll=3.4032, yaw=-53.0270, pitch=95.4167]
[x=-0.9692, y=-1.1287, z=-4.5847, roll=-0.3253, yaw=-12.2344, pitch=93.2270]
[x=-0.9694, y=-1.1287, z=-4.5845, roll=-2.9441, yaw=30.9962, pitch=93.5846]
[x=-0.9672, y=-1.1253, z=-4.5669, roll=-177.2290, yaw=121.4363, pitch=-94.9236]

# %% [markdown]
# 4个点处的yaw角度旋转数据（每次旋转43-46度）-----仅保留角度值

# %%
[
    [2.9726, 33.3364, 0.5471],
    [1.2630, 80.7374, 2.2648],
    [2.5626, 124.2558, 0.4429],
    [-2.1893, 167.4090, 0.1604],
    [-2.5408, -150.4331, 0.5022],
    [-0.4480, -101.3775, 2.1169],
    [2.8603, -57.9998, 1.4325],
    [2.5324, -55.4875, 91.6268],
    [179.5182, -101.1943, -91.5991],
    [-179.1793, -146.1972, -90.4901],
    [-178.7287, 168.6552, -90.3057],
    [-177.7245, 123.3208, -90.9030],
    [-0.2886, 80.7334, 92.1552],
    [1.3069, 32.1998, 90.6428],
    [1.7077, -57.5099, 90.4336],
    [2.5719, -54.3468, 93.9034],
    [0.3964, -52.7843, 91.9049],
    [-0.5675, -7.1385, 91.5855],
    [-2.0975, 34.0582, 91.7108],
    [-6.3252, 74.8816, 95.5746],
    [179.9958, 124.6180, -91.4012],
    [178.5895, 172.8003, -90.8504],
    [177.5008, -145.1366, -91.3455],
    [163.3548, -95.9682, -104.9276],
    [0.8704, -53.2292, 92.7668],
    [-0.4302, -6.7862, 93.0999],
    [-2.7291, 36.0104, 93.3343],
    [3.4032, -53.0270, 95.4167],
    [-0.3253, -12.2344, 93.2270],
    [-2.9441, 30.9962, 93.5846],
    [-177.2290, 121.4363, -94.9236]
]

# %% [markdown]
# 4个点处的yaw角度旋转数据（每次旋转43-46度）-----仅保留yaw角度值

# %%
    [0, 33.3364, 0],
    [0, 80.7374, 0],
    [0, 124.2558, 0],
    [0, 167.4090, 0],
    [0, -150.4331, 0],
    [0, -101.3775, 0],
    [0, -57.9998, 0],

# %% [markdown]
# 4个点处的yaw角度旋转数据（每次旋转43-46度）-----仅保留yaw角度值

# %%
[
    [0, -55.4875, 0],   #0
    [0, -101.1943, 0],  #-45.7068
    [0, -146.1972, 0],  #-90.7097
    [0, 168.6552, 0],   #-135.8027
    [0, 123.3208, 0],   #178.8677
    [0, 80.7334, 0],    #136.2333
    [0, 32.1998, 0],    #87.7123
    [0, -57.5099, 0],   #-2.0224
    [0, -54.3468, 0],   #1.1407
    [0, -52.7843, 0],   #2.7032
    [0, -7.1385, 0],    #48.349
    [0, 34.0582, 0],    #89.5457
    [0, 74.8816, 0],    #130.3691
    [0, 124.6180, 0],   #180.1055
    [0, 172.8003, 0],   #-131.7128
    [0, -145.1366, 0],  #-89.6491
    [0, -95.9682, 0],   #-40.4807
    [0, -53.2292, 0],   #2.2583
    [0, -6.7862, 0],    #48.7013
    [0, 36.0104, 0],    #91.4979
    [0, -53.0270, 0],   #2.4605
    [0, -12.2344, 0],   #43.2531
    [0, 30.9962, 0],    #86.4837
    [0, 121.4363, 0]    #176.9238
]

# %% [markdown]
# 对应列表A

# %%
orientations_A=
 [
    [np.radians(0), np.radians(-55.4875), np.radians(0)],
    [np.radians(0), np.radians(-101.1943), np.radians(0)],
    [np.radians(0), np.radians(-146.1972), np.radians(0)],
    [np.radians(0), np.radians(168.6552), np.radians(0)],
    [np.radians(0), np.radians(123.3208), np.radians(0)],
    [np.radians(0), np.radians(80.7334), np.radians(0)],
    [np.radians(0), np.radians(32.1998), np.radians(0)],
    [np.radians(0), np.radians(-57.5099), np.radians(0)],
    [np.radians(0), np.radians(-54.3468), np.radians(0)],
    [np.radians(0), np.radians(-52.7843), np.radians(0)],
    [np.radians(0), np.radians(-7.1385), np.radians(0)],
    [np.radians(0), np.radians(34.0582), np.radians(0)],
    [np.radians(0), np.radians(74.8816), np.radians(0)],
    [np.radians(0), np.radians(124.6180), np.radians(0)],
    [np.radians(0), np.radians(172.8003), np.radians(0)],
    [np.radians(0), np.radians(-145.1366), np.radians(0)],
    [np.radians(0), np.radians(-95.9682), np.radians(0)],
    [np.radians(0), np.radians(-53.2292), np.radians(0)],
    [np.radians(0), np.radians(-6.7862), np.radians(0)],
    [np.radians(0), np.radians(36.0104), np.radians(0)],
    [np.radians(0), np.radians(-53.0270), np.radians(0)],
    [np.radians(0), np.radians(-12.2344), np.radians(0)],
    [np.radians(0), np.radians(30.9962), np.radians(0)],
    [np.radians(0), np.radians(121.4363), np.radians(0)]
]

# %% [markdown]
# 对应B的方向

# %%
orientations_B=
 [
    [np.radians(0), np.radians(0), np.radians(0)],
    [np.radians(0), np.radians(-45.7068), np.radians(0)],
    [np.radians(0), np.radians(-90.7097), np.radians(0)],
    [np.radians(0), np.radians(-135.8027), np.radians(0)],
    [np.radians(0), np.radians(178.8677), np.radians(0)],
    [np.radians(0), np.radians(136.2333), np.radians(0)],
    [np.radians(0), np.radians(87.7123), np.radians(0)],
    [np.radians(0), np.radians(-2.0224), np.radians(0)],
    [np.radians(0), np.radians(1.1407), np.radians(0)],
    [np.radians(0), np.radians(2.7032), np.radians(0)],
    [np.radians(0), np.radians(48.349), np.radians(0)],
    [np.radians(0), np.radians(89.5457), np.radians(0)],
    [np.radians(0), np.radians(130.3691), np.radians(0)],
    [np.radians(0), np.radians(180.1055), np.radians(0)],
    [np.radians(0), np.radians(-131.7128), np.radians(0)],
    [np.radians(0), np.radians(-89.6491), np.radians(0)],
    [np.radians(0), np.radians(-40.4807), np.radians(0)],
    [np.radians(0), np.radians(2.2583), np.radians(0)],
    [np.radians(0), np.radians(48.7013), np.radians(0)],
    [np.radians(0), np.radians(91.4979), np.radians(0)],
    [np.radians(0), np.radians(2.4605), np.radians(0)],
    [np.radians(0), np.radians(43.2531), np.radians(0)],
    [np.radians(0), np.radians(86.4837), np.radians(0)],
    [np.radians(0), np.radians(176.9238), np.radians(0)]
]

# %% [markdown]
# 第四次采集，8个定位点数据

# %%
positions_A = [
    [0.488, -1.444, -3.911],  [x=0.4977, y=-1.3418, z=-3.9644, roll=0.5382, yaw=-56.4989, pitch=91.7965]
    [0.0995, -1.426, -3.322], [x=0.1037, y=-1.3499, z=-3.3650, roll=1.8766, yaw=-57.0828, pitch=92.4043]
    [-1.431, -1.396, -2.982], [x=-1.4171, y=-1.3479, z=-3.0228, roll=1.5893, yaw=-52.6989, pitch=92.0057]
    [-1.835, -1.391, -3.247], [x=-1.8228, y=-1.3415, z=-3.2905, roll=2.2694, yaw=-56.9973, pitch=92.8764]
    [-0.534, -1.399, -2.382], [x=-0.5198, y=-1.3533, z=-2.4208, roll=-0.2679, yaw=-57.0526, pitch=90.5055]
    [-1.426, -1.363, -1.053], [x=-1.4107, y=-1.3616, z=-1.0901, roll=0.4935, yaw=-56.9579, pitch=90.8430]
    [-1.547, -1.354, -0.883], [x=-1.5307, y=-1.3604, z=-0.9204, roll=0.4723, yaw=-53.4087, pitch=91.3814]
    [0.856, -1.416, -1.45]    [x=0.8781, y=-1.3749, z=-1.4890, roll=-1.1627, yaw=-58.1675, pitch=88.8565]
]

positions_B = [
    [0.217, 0, -2.05],
    [0.92, 0, -2.05],
    [2.05, 0, -0.97],
    [2.05, 0, -0.49],
    [2.05, 0, -2.05],
    [3.648, 0, -2.05],
    [3.858, 0, -2.05],
    [2.05, 0, -3.72]
]

# %% [markdown]
# 第五次采集，8个定位点的原始数据

# %%
[x=0.4977, y=-1.3418, z=-3.9644],
[x=0.1037, y=-1.3499, z=-3.3650],
[x=-1.4171, y=-1.3479, z=-3.0228],
[x=-1.8228, y=-1.3415, z=-3.2905],
[x=-0.5198, y=-1.3533, z=-2.4208],
[x=-1.4107, y=-1.3616, z=-1.0901],
[x=-1.5307, y=-1.3604, z=-0.9204],
[x=0.8781, y=-1.3749, z=-1.4890]

# %% [markdown]
# 第五次采集————8+16+11

# %%
positions_A = [
    [0.488, -1.444, -3.911],
    [0.0995, -1.426, -3.322],
    [-1.431, -1.396, -2.982],
    [-1.835, -1.391, -3.247],
    [-0.534, -1.399, -2.382],
    [-1.426, -1.363, -1.053],
    [-1.547, -1.354, -0.883],
    [0.856, -1.416, -1.45]
    [-1.1228, -1.3120, -4.3271],  # 1
    [-1.4121, -1.3142, -3.9064],  # 2
    [-0.9877, -1.3225, -3.6291],  # 3
    [-0.7143, -1.4099, -4.0170],  # 4
    [-2.2414, -1.3942, -2.6190],  # 5
    [-2.5227, -1.3905, -2.2047],  # 6
    [-2.1095, -1.3928, -1.9267],  # 7
    [-1.8286, -1.3967, -2.3420],  # 8
    [-0.0673, -1.3908, -1.1899],  # 9
    [-0.3366, -1.3817, -0.7836],  # 10
    [0.0801, -1.3763, -0.5090],   # 11
    [0.3583, -1.3796, -0.9285],   # 12
    [1.0222, -1.4046, -2.8521],   # 13
    [0.7512, -1.3999, -2.4198],   # 14
    [1.1732, -1.4018, -2.1531],   # 15
    [1.4524, -1.4044, -2.5697]    # 16
    [0.4918, -1.2814, -3.9277],
    [0.0803, -1.2843, -3.3221],
    [-1.4328, -1.3571, -3.0095],
    [-1.8315, -1.3566, -3.2634],
    [-0.5228, -1.3458, -2.4162],
    [-1.3939, -1.3780, -1.0774],
    [-1.5096, -1.3810, -0.9002],
    [0.8700, -1.3834, -1.4831],
    [-0.7353, -1.3912, -4.5095],
    [1.2387, -1.3820, -2.4318],
    [0.1353, -1.3768, -0.7140]
]
positions_B = [
    [0.217, 0, -2.05],
    [0.92, 0, -2.05],
    [2.05, 0, -0.97],
    [2.05, 0, -0.49],
    [2.05, 0, -2.05],
    [3.648, 0, -2.05],
    [3.858, 0, -2.05],
    [2.05, 0, -3.72]
    #1
    [0.80, 0, -0.503],   # 33
    [1.30, 0, -0.502],   # 34
    [0.80, 0, -1.001],   # 36
    [2.80, 0, -0.50],    # 37
    #2
    [3.30, 0, -0.50],    # 38
    [3.30, 0, -1.00],    # 39
    [2.80, 0, -1.00],    # 40
    [2.80, 0, -3.10],    # 41
    #3
    [3.30, 0, -3.10],    # 42
    [3.30, 0, -3.60],    # 43
    [2.80, 0, -3.60],    # 44
    [0.815, 0, -3.10],   # 45
    #4
    [1.316, 0, -3.10],   # 46
    [1.310, 0, -3.60],   # 47
    [0.808, 0, -3.60]    # 48
    [0.217, 0.08, -2.05],
    [0.92, 0.08, -2.05],
    [2.05, 0, -0.97],
    [2.05, 0, -0.49],
    [2.05, 0, -2.05],
    [3.648, 0, -2.05],
    [3.858, 0, -2.05],
    [2.05, 0, -3.72],
    [0.405, 0.004, -0.725],
    [1.053, 0.004, -3.507],
    [3.091, 0.004, -3.527]
]

# %% [markdown]
# 第六次采集，4个定位矩阵+两个横边的原始数据

# %%
# this is new point only care about positions
#1
[x=-1.1319, y=-1.3982, z=-4.3066, roll=-0.3748, yaw=-50.6959, pitch=90.6788]
[x=-1.1321, y=-1.3970, z=-4.3042, roll=-0.3259, yaw=-53.0529, pitch=90.4968]
#2
[x=-1.4152, y=-1.4541, z=-3.8460, roll=-2.3732, yaw=-54.1612, pitch=88.8639]
[x=-1.4132, y=-1.4533, z=-3.8437, roll=-2.2638, yaw=-51.8739, pitch=88.8087]
#3
[x=-0.9778, y=-1.3849, z=-3.6239, roll=2.8376, yaw=-51.8598, pitch=93.5971]
#4
[x=-0.7041, y=-1.4445, z=-4.0413, roll=1.6532, yaw=-55.6260, pitch=92.6084]
#1'
[x=-2.2357, y=-1.4714, z=-2.5922, roll=0.7544, yaw=-54.6313, pitch=91.3404]
#2'
[x=-2.5083, y=-1.4749, z=-2.1693, roll=1.0249, yaw=-50.1193, pitch=91.4885]
[x=-2.5068, y=-1.4505, z=-2.1799, roll=1.5663, yaw=-51.9607, pitch=90.3843]
#3'
[x=-2.0893, y=-1.4763, z=-1.9010, roll=1.1786, yaw=-53.0063, pitch=91.9179]
[x=-2.0895, y=-1.4759, z=-1.9011, roll=1.1963, yaw=-53.0177, pitch=91.9777]
#4'
[x=-1.8161, y=-1.4764, z=-2.3207, roll=1.5694, yaw=-53.7947, pitch=91.5578]
#1''
[x=-0.0468, y=-1.4752, z=-1.1820, roll=2.1419, yaw=-56.9116, pitch=92.7519]
#2''
[x=-0.3184, y=-1.4779, z=-0.7581, roll=0.4871, yaw=-58.3867, pitch=91.2462]
#3''
[x=0.0939, y=-1.4746, z=-0.4933, roll=0.5999, yaw=-55.3429, pitch=90.6760]
#4''
[x=0.3747, y=-1.4740, z=-0.9140, roll=-0.0702, yaw=-57.5514, pitch=90.2575]
#1'''
[x=1.0288, y=-1.4536, z=-2.8581, roll=2.1348, yaw=-58.4311, pitch=91.8629]
#2'''
[x=0.7589, y=-1.4609, z=-2.4383, roll=1.6910, yaw=-59.0328, pitch=91.5962]
#3'''
[x=1.1871, y=-1.4622, z=-2.1691, roll=2.1029, yaw=-58.4671, pitch=91.4960]
#4'''
[x=1.4569, y=-1.4565, z=-2.5930, roll=2.3462, yaw=-60.0523, pitch=91.9351]
#11
[x=0.0973, y=-1.4441, z=-4.1960, roll=2.6122, yaw=-57.1369, pitch=91.7425]
##22
[x=-0.2736, y=-1.4450, z=-4.4384, roll=1.5953, yaw=-56.1759, pitch=91.6599]
##33
[x=0.8952, y=-1.4434, z=-3.6727, roll=1.1664, yaw=-56.5262, pitch=91.7143]
##44
[x=1.2936, y=-1.4443, z=-3.4120, roll=1.5926, yaw=-56.1318, pitch=92.0032]

# %% [markdown]
# 第六次采集，4个定位矩阵+两个横边的仅保留 坐标数据

# %%
    # 1
    [-1.1320, -1.3976, -4.3054],
    # 2
    [-1.4142, -1.4537, -3.84485],
    # 3
    [-0.9778, -1.3849, -3.6239],
    # 4
    [-0.7041, -1.4445, -4.0413],
    # 1'
    [-2.2357, -1.4714, -2.5922],
    # 2'
    [-2.50755, -1.4627, -2.1746],
    # 3'
    [-2.0894, -1.4761, -1.90105],
    # 4'
    [-1.8161, -1.4764, -2.3207],
    # 1''
    [-0.0468, -1.4752, -1.1820],
    # 2''
    [-0.3184, -1.4779, -0.7581],
    # 3''
    [0.0939, -1.4746, -0.4933],
    # 4''
    [0.3747, -1.4740, -0.9140],
    # 1'''
    [1.0288, -1.4536, -2.8581],
    # 2'''
    [0.7589, -1.4609, -2.4383],
    # 3'''
    [1.1871, -1.4622, -2.1691],
    # 4'''
    [1.4569, -1.4565, -2.5930],


    # 11
    [0.0973, -1.4441, -4.1960],
    # 22
    [-0.2736, -1.4450, -4.4384],
    # 33
    [0.8952, -1.4434, -3.6727],
    # 44
    [1.2936, -1.4443, -3.4120],

######for sandbox
    #1
    [0.80,  0, -0.503],   #8 33
    [1.30,  0, -0.502],   #9 34
    [1.30,  0, -1.001],   #10 35
    [0.80,  0, -1.001],   #11 36
    #2
    [2.80,  0, -0.50],    #12 37
    [3.30,  0, -0.50],    #13 38
    [3.30,  0, -1.00],    #14 39
    [2.80,  0, -1.00],    #15 40
    #3
    [2.80,  0, -3.10],    #16 41
    [3.30,  0, -3.10],    # 42
    [3.30,  0, -3.60],    # 43
    [2.80,  0, -3.60],    # 44
    #4
    [0.815, 0, -3.10],   # 45
    [1.316, 0, -3.10],   # 46
    [1.310, 0, -3.60],   # 47
    [0.808, 0, -3.60],   # 48
    ##11
    [0.199,   0,    -1.595],
    ##22
    [0.199,   0,    -1.153],
    ##33
    [0.209,   0,    -2.547],
    ##44
    [0.209,   0,    -3.023]

# %% [markdown]
# 第七次采集 8+6+3+8

# %%
#this is 180724 15:35 all points with msn (RMSE): 0.0526 m
positions_A = [
    #8 points
    [0.4977,  -1.3418, -3.9644],
    [0.1037,  -1.3499, -3.3650],
    [-1.4171, -1.3479, -3.0228],
    [-1.8228, -1.3415, -3.2905],
    [-0.5198, -1.3533, -2.4208],
    [-1.4107, -1.3616, -1.0901],
    [-1.5307, -1.3604, -0.9204],
    [0.8781,  -1.3749, -1.4890],
    ### 6
    [-1.4328, -1.3571, -3.0095],
    [-1.8315, -1.3566, -3.2634],
    [-0.5228, -1.3458, -2.4162],
    [-1.3939, -1.3780, -1.0774],
    [-1.5096, -1.3810, -0.9002],
    [0.8700,  -1.3834, -1.4831],
    ###
    [-0.7353, -1.3912, -4.5095],
    [1.2387,  -1.3820, -2.4318],
    [0.1353,  -1.3768, -0.7140],

    ### 4 matrix
        # 1
    [-1.1320, -1.3976, -4.3054],
    # 2
    [-1.4142, -1.4537, -3.84485],
    # 3
    [-0.9778, -1.3849, -3.6239],
    # 4
    [-0.7041, -1.4445, -4.0413],
    # 1'
    [-2.2357, -1.4714, -2.5922],
    # 2'
    [-2.50755, -1.4627, -2.1746],
    # 3'
    [-2.0894, -1.4761, -1.90105],
    # 4'
    [-1.8161, -1.4764, -2.3207],
    # 1''
    [-0.0468, -1.4752, -1.1820],
    # 2''
    [-0.3184, -1.4779, -0.7581],
    # 3''
    [0.0939, -1.4746, -0.4933],
    # 4''
    [0.3747, -1.4740, -0.9140],
    # 1'''
    [1.0288, -1.4536, -2.8581],
    # 2'''
    [0.7589, -1.4609, -2.4383],
    # 3'''
    [1.1871, -1.4622, -2.1691],
    # 4'''
    [1.4569, -1.4565, -2.5930],

    # 11
    [0.0973, -1.4441, -4.1960],
    # 22
    [-0.2736, -1.4450, -4.4384],
    # 33
    [0.8952, -1.4434, -3.6727],
    # 44
    [1.2936, -1.4443, -3.4120],

]
positions_B = [
    [0.217, 0, -2.05],    #0
    [0.92,  0, -2.05],    #1
    [2.05,  0, -0.97],    #2
    [2.05,  0, -0.49],    #3
    [2.05,  0, -2.05],    #4
    [3.648, 0, -2.05],    #5
    [3.858, 0, -2.05],    #6
    [2.05,  0, -3.72],    #7

    [2.05,  0, -0.97],
    [2.05,  0, -0.49],
    [2.05,  0, -2.05],
    [3.648, 0, -2.05],
    [3.858, 0, -2.05],
    [2.05,  0, -3.72],

    [0.405, 0.004, -0.725],
    [1.053, 0.004, -3.507],
    [3.091, 0.004, -3.527],

    [0.80,  0, -0.503],   #8 33
    [1.30,  0, -0.502],   #9 34
    [1.30,  0, -1.001],   #10 35
    [0.80,  0, -1.001],   #11 36

    [2.80,  0, -0.50],    #12 37
    [3.30,  0, -0.50],    #13 38
    [3.30,  0, -1.00],    #14 39
    [2.80,  0, -1.00],    #15 40

    [2.80,  0, -3.10],    #16 41
    [3.30,  0, -3.10],    # 42
    [3.30,  0, -3.60],    # 43
    [2.80,  0, -3.60],    # 44

    [0.815, 0, -3.10],   # 45
    [1.316, 0, -3.10],   # 46
    [1.310, 0, -3.60],   # 47
    [0.808, 0, -3.60],   # 48

    ##11
    [0.199,   0,    -1.595],
    ##22
    [0.199,   0,    -1.153],
    ##33
    [0.209,   0,    -2.547],
    ##44
    [0.209,   0,    -3.023]


]

# %% [markdown]
# 设置所有y为0

# %%
#here we set all y as 0

positions_A = [
    # 8 points
    [0.4977,  0, -3.9644],
    [0.1037,  0, -3.3650],
    [-1.4171, 0, -3.0228],
    [-1.8228, 0, -3.2905],
    [-0.5198, 0, -2.4208],
    [-1.4107, 0, -1.0901],
    [-1.5307, 0, -0.9204],
    [0.8781,  0, -1.4890],
    ### 6
    [-1.4328, 0, -3.0095],
    [-1.8315, 0, -3.2634],
    [-0.5228, 0, -2.4162],
    [-1.3939, 0, -1.0774],
    [-1.5096, 0, -0.9002],
    [0.8700,  0, -1.4831],
    ###
    [-0.7353, 0, -4.5095],
    [1.2387,  0, -2.4318],
    [0.1353,  0, -0.7140],

    ### 4 matrix
    # 1
    [-1.1320, 0, -4.3054],
    # 2
    [-1.4142, 0, -3.84485],
    # 3
    [-0.9778, 0, -3.6239],
    # 4
    [-0.7041, 0, -4.0413],
    # 1'
    [-2.2357, 0, -2.5922],
    # 2'
    [-2.50755, 0, -2.1746],
    # 3'
    [-2.0894, 0, -1.90105],
    # 4'
    [-1.8161, 0, -2.3207],
    # 1''
    [-0.0468, 0, -1.1820],
    # 2''
    [-0.3184, 0, -0.7581],
    # 3''
    [0.0939, 0, -0.4933],
    # 4''
    [0.3747, 0, -0.9140],
    # 1'''
    [1.0288, 0, -2.8581],
    # 2'''
    [0.7589, 0, -2.4383],
    # 3'''
    [1.1871, 0, -2.1691],
    # 4'''
    [1.4569, 0, -2.5930],

    # 11
    [0.0973, 0, -4.1960],
    # 22
    [-0.2736, 0, -4.4384],
    # 33
    [0.8952, 0, -3.6727],
    # 44
    [1.2936, 0, -3.4120],
]

positions_B = [
    [0.217, 0, -2.05],    #0
    [0.92,  0, -2.05],    #1
    [2.05,  0, -0.97],    #2
    [2.05,  0, -0.49],    #3
    [2.05,  0, -2.05],    #4
    [3.648, 0, -2.05],    #5
    [3.858, 0, -2.05],    #6
    [2.05,  0, -3.72],    #7

    [2.05,  0, -0.97],
    [2.05,  0, -0.49],
    [2.05,  0, -2.05],
    [3.648, 0, -2.05],
    [3.858, 0, -2.05],
    [2.05,  0, -3.72],

    [0.405, 0.004, -0.725],
    [1.053, 0.004, -3.507],
    [3.091, 0.004, -3.527],

    [0.80,  0, -0.503],   #8 33
    [1.30,  0, -0.502],   #9 34
    [1.30,  0, -1.001],   #10 35
    [0.80,  0, -1.001],   #11 36

    [2.80,  0, -0.50],    #12 37
    [3.30,  0, -0.50],    #13 38
    [3.30,  0, -1.00],    #14 39
    [2.80,  0, -1.00],    #15 40

    [2.80,  0, -3.10],    #16 41
    [3.30,  0, -3.10],    # 42
    [3.30,  0, -3.60],    # 43
    [2.80,  0, -3.60],    # 44

    [0.815, 0, -3.10],   # 45
    [1.316, 0, -3.10],   # 46
    [1.310, 0, -3.60],   # 47
    [0.808, 0, -3.60],   # 48

    ##11
    [0.199,   0,    -1.595],
    ##22
    [0.199,   0,    -1.153],
    ##33
    [0.209,   0,    -2.547],
    ##44
    [0.209,   0,    -3.023]


]

# %% [markdown]
# 第8次采集

# %%
##this is for the new point

#1
[x=0.4840, y=-1.3527, z=-3.9304, roll=-0.2233, yaw=-54.7451, pitch=90.9923]
[x=0.4959, y=-1.3791, z=-3.9563, roll=-0.7151, yaw=34.1769, pitch=90.2408]
[x=0.4751, y=-1.3617, z=-3.9276, roll=0.8854, yaw=-57.9565, pitch=90.8509]
[x=0.4715, y=-1.2578, z=-3.9575, roll=2.9338, yaw=-57.1688, pitch=92.8503]
[x=0.4827, y=-1.3510, z=-3.9244, roll=-0.4266, yaw=-56.7461, pitch=90.9467]
#2
[x=0.0877, y=-1.2857, z=-3.3653, roll=4.6835, yaw=-56.1893, pitch=93.6497]
[x=0.0868, y=-1.3690, z=-3.3255, roll=2.2226, yaw=-54.8505, pitch=91.5840]
#3
[x=-1.4214, y=-1.3894, z=-3.0220, roll=1.7544, yaw=-54.9754, pitch=91.5219]
[x=-1.4308, y=-1.3915, z=-2.9704, roll=3.0007, yaw=-53.4949, pitch=92.2546]
#4
[x=-1.8283, y=-1.3841, z=-3.2823, roll=1.1904, yaw=-55.3863, pitch=90.2913]
[x=-1.8356, y=-1.3872, z=-3.2574, roll=1.5975, yaw=-56.6297, pitch=91.9554]
[x=-1.8396, y=-1.3300, z=-3.2869, roll=2.2748, yaw=-56.1704, pitch=92.8103]
#5
[x=-0.5324, y=-1.3426, z=-2.4248, roll=0.3368, yaw=-56.3205, pitch=91.3182]
#8
[x=0.8592, y=-1.3671, z=-1.4793, roll=-1.4186, yaw=-56.5614, pitch=88.7630]
#a
[x=1.0574, y=-1.3686, z=-1.7693, roll=0.2682, yaw=-57.8034, pitch=89.8852]
#b
[x=1.2512, y=-1.3716, z=-2.0666, roll=0.3054, yaw=-57.6427, pitch=89.3120]
#c
[x=0.6942, y=-1.3650, z=-1.2022, roll=-0.2071, yaw=-58.1462, pitch=88.9853]
[x=0.7020, y=-1.3712, z=-1.2216, roll=0.9044, yaw=-57.1096, pitch=90.8669]
[x=0.7044, y=-1.3714, z=-1.2210, roll=0.9196, yaw=-56.6877, pitch=90.9650]
#d
[x=0.4604, y=-1.3625, z=-0.8474, roll=-0.3380, yaw=-57.3716, pitch=89.4768]

# %%
       # 1
    [0.48184, -1.34046, -3.93924],
    # 2
    [0.08725, -1.32735, -3.3454],
    # 3
    [-1.4261, -1.39045, -2.9962],
    # 4
    [-1.83450, -1.36710, -3.27553],
    # 5
    [-0.5324, -1.3426, -2.4248],
    # 8
    [0.8592, -1.3671, -1.4793],
    # a
    [1.0574, -1.3686, -1.7693],
    # b
    [1.2512, -1.3716, -2.0666],
    # c
    [0.6942, -1.3650, -1.2022],
    # d
    [0.4604, -1.3625, -0.8474]
   #####################################
    [0.217, 0, -2.05],    #1
    [0.92,  0, -2.05],    #2
    [2.05,  0, -0.97],    #3
    [2.05,  0, -0.49],    #4
    [2.05,  0, -2.05],    #5
    [2.05,  0, -3.72],    #8
    #a
    [1.7,0,-3.726],
    [1.343,0,-3.723],
    [2.473,0,-3.733],
    [2.795,0,-3.738]

# %% [markdown]
# 最终使用数据

# %%
#here we set all y as 0

positions_A = [
    # 8 points
    # 1
    [0.48184, 0, -3.93924],
    # 2
    [0.08725, 0, -3.3454],
    # 3
    [-1.4261, 0, -2.9962],
    # 4
    [-1.83450, -0, -3.27553],
    # 5
    [-0.5324, 0, -2.4248],
    # 8
    [0.8592, 0, -1.4793],
    # a
    [1.0574, 0, -1.7693],
    # b
    [1.2512, 0, -2.0666],
    # c##############################
    #[0.7020, 0, -1.2212],
    # d,
    [0.4604, 0, -0.8474],

    ### 4 matrix
    # 1
    [-1.1320, 0, -4.3054],
    # 2
    [-1.4142, 0, -3.84485],
    # 3
    [-0.9778, 0, -3.6239],
    # 4
    [-0.7041, 0, -4.0413],
    # 1'
    [-2.2357, 0, -2.5922],
    # 2'
    [-2.50755, 0, -2.1746],
    # 3'
    [-2.0894, 0, -1.90105],
    # 4'
    [-1.8161, 0, -2.3207],
    # 1''
    [-0.0468, 0, -1.1820],
    # 2''
    [-0.3184, 0, -0.7581],
    # 3''
    [0.0939, 0, -0.4933],
    # 4''
    [0.3747, 0, -0.9140],
    # 1'''
    [1.0288, 0, -2.8581],
    # 2'''
    [0.7589, 0, -2.4383],
    # 3'''
    [1.1871, 0, -2.1691],
    # 4'''
    [1.4569, 0, -2.5930],

    # 11
    [0.0973, 0, -4.1960],
    # 22
    [-0.2736, 0, -4.4384],
    # 33
    [0.8952, 0, -3.6727],
    # 44
    [1.2936, 0, -3.4120],
]

positions_B = [
    [0.217, 0, -2.05],    #1
    [0.92,  0, -2.05],    #2
    [2.05,  0, -0.97],    #3
    [2.05,  0, -0.49],    #4
    [2.05,  0, -2.05],    #5
    [2.05,  0, -3.72],    #8
    #a
    [1.7,0,-3.726],
    #b
    [1.343,0,-3.723],
    #c#####################
    #[2.473,0,-3.733],
    #d
    [2.795,0,-3.738],

    [0.80,  0, -0.503],   #8 33
    [1.30,  0, -0.502],   #9 34
    [1.30,  0, -1.001],   #10 35
    [0.80,  0, -1.001],   #11 36

    [2.80,  0, -0.50],    #12 37
    [3.30,  0, -0.50],    #13 38
    [3.30,  0, -1.00],    #14 39
    [2.80,  0, -1.00],    #15 40

    [2.80,  0, -3.10],    #16 41
    [3.30,  0, -3.10],    # 42
    [3.30,  0, -3.60],    # 43
    [2.80,  0, -3.60],    # 44

    [0.815, 0, -3.10],   # 45
    [1.316, 0, -3.10],   # 46
    [1.310, 0, -3.60],   # 47
    [0.808, 0, -3.60],   # 48

    ##11
    [0.199,   0,    -1.595],
    ##22
    [0.199,   0,    -1.153],
    ##33
    [0.209,   0,    -2.547],
    ##44
    [0.209,   0,    -3.023]


]

# %% [markdown]
# 测试数据

# %%
# data for test
#T1
[x=-0.1095, y=-1.3573, z=-4.3822, roll=1.7546, yaw=-58.1645, pitch=93.0677]
[-0.1095,0,-4.3822]
#######real
[0.1980,0,-1.337]
#T2
[x=0.7333, y=-1.3383, z=-3.7766, roll=0.7334, yaw=-56.6314, pitch=91.8683]
[0.7333,0,-3.7766]
#######real
[0.207,0,-2.346]
